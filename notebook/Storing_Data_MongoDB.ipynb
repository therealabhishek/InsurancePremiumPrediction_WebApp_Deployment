# %%
import pandas as pd
import pymongo

# %%
# reading the data:

df = pd.read_csv('../data/insurance.csv')
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
data = df.to_dict(orient='records')
data
# Out:
# [{'age': 19,
#   'sex': 'female',
#   'bmi': 27.9,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 16884.92},
#  {'age': 18,
#   'sex': 'male',
#   'bmi': 33.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 1725.55},
#  {'age': 28,
#   'sex': 'male',
#   'bmi': 33.0,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 4449.46},
#  {'age': 33,
#   'sex': 'male',
#   'bmi': 22.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 21984.47},
#  {'age': 32,
#   'sex': 'male',
#   'bmi': 28.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 3866.86},
#  {'age': 31,
#   'sex': 'female',
#   'bmi': 25.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 3756.62},
#  {'age': 46,
#   'sex': 'female',
#   'bmi': 33.4,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 8240.59},
#  {'age': 37,
#   'sex': 'female',
#   'bmi': 27.7,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 7281.51},
#  {'age': 37,
#   'sex': 'male',
#   'bmi': 29.8,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 6406.41},
#  {'age': 60,
#   'sex': 'female',
#   'bmi': 25.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 28923.14},
#  {'age': 25,
#   'sex': 'male',
#   'bmi': 26.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 2721.32},
#  {'age': 62,
#   'sex': 'female',
#   'bmi': 26.3,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 27808.73},
#  {'age': 23,
#   'sex': 'male',
#   'bmi': 34.4,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 1826.84},
#  {'age': 56,
#   'sex': 'female',
#   'bmi': 39.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 11090.72},
#  {'age': 27,
#   'sex': 'male',
#   'bmi': 42.1,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 39611.76},
#  {'age': 19,
#   'sex': 'male',
#   'bmi': 24.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 1837.24},
#  {'age': 52,
#   'sex': 'female',
#   'bmi': 30.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 10797.34},
#  {'age': 23,
#   'sex': 'male',
#   'bmi': 23.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 2395.17},
#  {'age': 56,
#   'sex': 'male',
#   'bmi': 40.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 10602.39},
#  {'age': 30,
#   'sex': 'male',
#   'bmi': 35.3,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 36837.47},
#  {'age': 60,
#   'sex': 'female',
#   'bmi': 36.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 13228.85},
#  {'age': 30,
#   'sex': 'female',
#   'bmi': 32.4,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 4149.74},
#  {'age': 18,
#   'sex': 'male',
#   'bmi': 34.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 1137.01},
#  {'age': 34,
#   'sex': 'female',
#   'bmi': 31.9,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 37701.88},
#  {'age': 37,
#   'sex': 'male',
#   'bmi': 28.0,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 6203.9},
#  {'age': 59,
#   'sex': 'female',
#   'bmi': 27.7,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 14001.13},
#  {'age': 63,
#   'sex': 'female',
#   'bmi': 23.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 14451.84},
#  {'age': 55,
#   'sex': 'female',
#   'bmi': 32.8,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 12268.63},
#  {'age': 23,
#   'sex': 'male',
#   'bmi': 17.4,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2775.19},
#  {'age': 31,
#   'sex': 'male',
#   'bmi': 36.3,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 38711.0},
#  {'age': 22,
#   'sex': 'male',
#   'bmi': 35.6,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 35585.58},
#  {'age': 18,
#   'sex': 'female',
#   'bmi': 26.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 2198.19},
#  {'age': 19,
#   'sex': 'female',
#   'bmi': 28.6,
#   'children': 5,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 4687.8},
#  {'age': 63,
#   'sex': 'male',
#   'bmi': 28.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 13770.1},
#  {'age': 28,
#   'sex': 'male',
#   'bmi': 36.4,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 51194.56},
#  {'age': 19,
#   'sex': 'male',
#   'bmi': 20.4,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 1625.43},
#  {'age': 62,
#   'sex': 'female',
#   'bmi': 33.0,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 15612.19},
#  {'age': 26,
#   'sex': 'male',
#   'bmi': 20.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 2302.3},
#  {'age': 35,
#   'sex': 'male',
#   'bmi': 36.7,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 39774.28},
#  {'age': 60,
#   'sex': 'male',
#   'bmi': 39.9,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 48173.36},
#  {'age': 24,
#   'sex': 'female',
#   'bmi': 26.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 3046.06},
#  {'age': 31,
#   'sex': 'female',
#   'bmi': 36.6,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 4949.76},
#  {'age': 41,
#   'sex': 'male',
#   'bmi': 21.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 6272.48},
#  {'age': 37,
#   'sex': 'female',
#   'bmi': 30.8,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 6313.76},
#  {'age': 38,
#   'sex': 'male',
#   'bmi': 37.1,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 6079.67},
#  {'age': 55,
#   'sex': 'male',
#   'bmi': 37.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 20630.28},
#  {'age': 18,
#   'sex': 'female',
#   'bmi': 38.7,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 3393.36},
#  {'age': 28,
#   'sex': 'female',
#   'bmi': 34.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 3556.92},
#  {'age': 60,
#   'sex': 'female',
#   'bmi': 24.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 12629.9},
#  {'age': 36,
#   'sex': 'male',
#   'bmi': 35.2,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 38709.18},
#  {'age': 18,
#   'sex': 'female',
#   'bmi': 35.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 2211.13},
#  {'age': 21,
#   'sex': 'female',
#   'bmi': 33.6,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 3579.83},
#  {'age': 48,
#   'sex': 'male',
#   'bmi': 28.0,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 23568.27},
#  {'age': 36,
#   'sex': 'male',
#   'bmi': 34.4,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 37742.58},
#  {'age': 40,
#   'sex': 'female',
#   'bmi': 28.7,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 8059.68},
#  {'age': 58,
#   'sex': 'male',
#   'bmi': 37.0,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 47496.49},
#  {'age': 58,
#   'sex': 'female',
#   'bmi': 31.8,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 13607.37},
#  {'age': 18,
#   'sex': 'male',
#   'bmi': 31.7,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 34303.17},
#  {'age': 53,
#   'sex': 'female',
#   'bmi': 22.9,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 23244.79},
#  {'age': 34,
#   'sex': 'female',
#   'bmi': 37.3,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 5989.52},
#  {'age': 43,
#   'sex': 'male',
#   'bmi': 27.4,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 8606.22},
#  {'age': 25,
#   'sex': 'male',
#   'bmi': 33.7,
#   'children': 4,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 4504.66},
#  {'age': 64,
#   'sex': 'male',
#   'bmi': 24.7,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 30166.62},
#  {'age': 28,
#   'sex': 'female',
#   'bmi': 25.9,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 4133.64},
#  {'age': 20,
#   'sex': 'female',
#   'bmi': 22.4,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 14711.74},
#  {'age': 19,
#   'sex': 'female',
#   'bmi': 28.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 1743.21},
#  {'age': 61,
#   'sex': 'female',
#   'bmi': 39.1,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 14235.07},
#  {'age': 40,
#   'sex': 'male',
#   'bmi': 26.3,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 6389.38},
#  {'age': 40,
#   'sex': 'female',
#   'bmi': 36.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 5920.1},
#  {'age': 28,
#   'sex': 'male',
#   'bmi': 24.0,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 17663.14},
#  {'age': 27,
#   'sex': 'female',
#   'bmi': 24.8,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 16577.78},
#  {'age': 31,
#   'sex': 'male',
#   'bmi': 28.5,
#   'children': 5,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 6799.46},
#  {'age': 53,
#   'sex': 'female',
#   'bmi': 28.1,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 11741.73},
#  {'age': 58,
#   'sex': 'male',
#   'bmi': 32.0,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 11946.63},
#  {'age': 44,
#   'sex': 'male',
#   'bmi': 27.4,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 7726.85},
#  {'age': 57,
#   'sex': 'male',
#   'bmi': 34.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 11356.66},
#  {'age': 29,
#   'sex': 'female',
#   'bmi': 29.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 3947.41},
#  {'age': 21,
#   'sex': 'male',
#   'bmi': 35.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 1532.47},
#  {'age': 22,
#   'sex': 'female',
#   'bmi': 39.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 2755.02},
#  {'age': 41,
#   'sex': 'female',
#   'bmi': 33.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 6571.02},
#  {'age': 31,
#   'sex': 'male',
#   'bmi': 26.9,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4441.21},
#  {'age': 45,
#   'sex': 'female',
#   'bmi': 38.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 7935.29},
#  {'age': 22,
#   'sex': 'male',
#   'bmi': 37.6,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 37165.16},
#  {'age': 48,
#   'sex': 'female',
#   'bmi': 41.2,
#   'children': 4,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 11033.66},
#  {'age': 37,
#   'sex': 'female',
#   'bmi': 34.8,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 39836.52},
#  {'age': 45,
#   'sex': 'male',
#   'bmi': 22.9,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 21098.55},
#  {'age': 57,
#   'sex': 'female',
#   'bmi': 31.2,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 43578.94},
#  {'age': 56,
#   'sex': 'female',
#   'bmi': 27.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 11073.18},
#  {'age': 46,
#   'sex': 'female',
#   'bmi': 27.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 8026.67},
#  {'age': 55,
#   'sex': 'female',
#   'bmi': 27.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 11082.58},
#  {'age': 21,
#   'sex': 'female',
#   'bmi': 39.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2026.97},
#  {'age': 53,
#   'sex': 'female',
#   'bmi': 24.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 10942.13},
#  {'age': 59,
#   'sex': 'male',
#   'bmi': 29.8,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 30184.94},
#  {'age': 35,
#   'sex': 'male',
#   'bmi': 34.8,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 5729.01},
#  {'age': 64,
#   'sex': 'female',
#   'bmi': 31.3,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 47291.06},
#  {'age': 28,
#   'sex': 'female',
#   'bmi': 37.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 3766.88},
#  {'age': 54,
#   'sex': 'female',
#   'bmi': 30.8,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 12105.32},
#  {'age': 55,
#   'sex': 'male',
#   'bmi': 38.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 10226.28},
#  {'age': 56,
#   'sex': 'male',
#   'bmi': 20.0,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 22412.65},
#  {'age': 38,
#   'sex': 'male',
#   'bmi': 19.3,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 15820.7},
#  {'age': 41,
#   'sex': 'female',
#   'bmi': 31.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 6186.13},
#  {'age': 30,
#   'sex': 'male',
#   'bmi': 25.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 3645.09},
#  {'age': 18,
#   'sex': 'female',
#   'bmi': 30.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 21344.85},
#  {'age': 61,
#   'sex': 'female',
#   'bmi': 29.9,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 30942.19},
#  {'age': 34,
#   'sex': 'female',
#   'bmi': 27.5,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 5003.85},
#  {'age': 20,
#   'sex': 'male',
#   'bmi': 28.0,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 17560.38},
#  {'age': 19,
#   'sex': 'female',
#   'bmi': 28.4,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 2331.52},
#  {'age': 26,
#   'sex': 'male',
#   'bmi': 30.9,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 3877.3},
#  {'age': 29,
#   'sex': 'male',
#   'bmi': 27.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2867.12},
#  {'age': 63,
#   'sex': 'male',
#   'bmi': 35.1,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 47055.53},
#  {'age': 54,
#   'sex': 'male',
#   'bmi': 33.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 10825.25},
#  {'age': 55,
#   'sex': 'female',
#   'bmi': 29.7,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 11881.36},
#  {'age': 37,
#   'sex': 'male',
#   'bmi': 30.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 4646.76},
#  {'age': 21,
#   'sex': 'female',
#   'bmi': 35.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2404.73},
#  {'age': 52,
#   'sex': 'male',
#   'bmi': 32.2,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 11488.32},
#  {'age': 60,
#   'sex': 'male',
#   'bmi': 28.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 30260.0},
#  {'age': 58,
#   'sex': 'male',
#   'bmi': 49.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 11381.33},
#  {'age': 29,
#   'sex': 'female',
#   'bmi': 27.9,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 19107.78},
#  {'age': 49,
#   'sex': 'female',
#   'bmi': 27.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 8601.33},
#  {'age': 37,
#   'sex': 'female',
#   'bmi': 23.4,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 6686.43},
#  {'age': 44,
#   'sex': 'male',
#   'bmi': 37.1,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 7740.34},
#  {'age': 18,
#   'sex': 'male',
#   'bmi': 23.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 1705.62},
#  {'age': 20,
#   'sex': 'female',
#   'bmi': 29.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2257.48},
#  {'age': 44,
#   'sex': 'male',
#   'bmi': 31.4,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 39556.49},
#  {'age': 47,
#   'sex': 'female',
#   'bmi': 33.9,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 10115.01},
#  {'age': 26,
#   'sex': 'female',
#   'bmi': 28.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 3385.4},
#  {'age': 19,
#   'sex': 'female',
#   'bmi': 28.3,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 17081.08},
#  {'age': 52,
#   'sex': 'female',
#   'bmi': 37.4,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 9634.54},
#  {'age': 32,
#   'sex': 'female',
#   'bmi': 17.8,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 32734.19},
#  {'age': 38,
#   'sex': 'male',
#   'bmi': 34.7,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 6082.41},
#  {'age': 59,
#   'sex': 'female',
#   'bmi': 26.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 12815.44},
#  {'age': 61,
#   'sex': 'female',
#   'bmi': 22.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 13616.36},
#  {'age': 53,
#   'sex': 'female',
#   'bmi': 35.9,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 11163.57},
#  {'age': 19,
#   'sex': 'male',
#   'bmi': 25.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 1632.56},
#  {'age': 20,
#   'sex': 'female',
#   'bmi': 28.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 2457.21},
#  {'age': 22,
#   'sex': 'female',
#   'bmi': 28.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2155.68},
#  {'age': 19,
#   'sex': 'male',
#   'bmi': 34.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 1261.44},
#  {'age': 22,
#   'sex': 'male',
#   'bmi': 25.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2045.69},
#  {'age': 54,
#   'sex': 'female',
#   'bmi': 31.9,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 27322.73},
#  {'age': 22,
#   'sex': 'female',
#   'bmi': 36.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 2166.73},
#  {'age': 34,
#   'sex': 'male',
#   'bmi': 22.4,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 27375.9},
#  {'age': 26,
#   'sex': 'male',
#   'bmi': 32.5,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 3490.55},
#  {'age': 34,
#   'sex': 'male',
#   'bmi': 25.3,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 18972.5},
#  {'age': 29,
#   'sex': 'male',
#   'bmi': 29.7,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 18157.88},
#  {'age': 30,
#   'sex': 'male',
#   'bmi': 28.7,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 20745.99},
#  {'age': 29,
#   'sex': 'female',
#   'bmi': 38.8,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 5138.26},
#  {'age': 46,
#   'sex': 'male',
#   'bmi': 30.5,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 40720.55},
#  {'age': 51,
#   'sex': 'female',
#   'bmi': 37.7,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 9877.61},
#  {'age': 53,
#   'sex': 'female',
#   'bmi': 37.4,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 10959.69},
#  {'age': 19,
#   'sex': 'male',
#   'bmi': 28.4,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 1842.52},
#  {'age': 35,
#   'sex': 'male',
#   'bmi': 24.1,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 5125.22},
#  {'age': 48,
#   'sex': 'male',
#   'bmi': 29.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 7789.64},
#  {'age': 32,
#   'sex': 'female',
#   'bmi': 37.1,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 6334.34},
#  {'age': 42,
#   'sex': 'female',
#   'bmi': 23.4,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 19964.75},
#  {'age': 40,
#   'sex': 'female',
#   'bmi': 25.5,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 7077.19},
#  {'age': 44,
#   'sex': 'male',
#   'bmi': 39.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 6948.7},
#  {'age': 48,
#   'sex': 'male',
#   'bmi': 24.4,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 21223.68},
#  {'age': 18,
#   'sex': 'male',
#   'bmi': 25.2,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 15518.18},
#  {'age': 30,
#   'sex': 'male',
#   'bmi': 35.5,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 36950.26},
#  {'age': 50,
#   'sex': 'female',
#   'bmi': 27.8,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 19749.38},
#  {'age': 42,
#   'sex': 'female',
#   'bmi': 26.6,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 21348.71},
#  {'age': 18,
#   'sex': 'female',
#   'bmi': 36.9,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 36149.48},
#  {'age': 54,
#   'sex': 'male',
#   'bmi': 39.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 10450.55},
#  {'age': 32,
#   'sex': 'female',
#   'bmi': 29.8,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 5152.13},
#  {'age': 37,
#   'sex': 'male',
#   'bmi': 29.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 5028.15},
#  {'age': 47,
#   'sex': 'male',
#   'bmi': 28.2,
#   'children': 4,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 10407.09},
#  {'age': 20,
#   'sex': 'female',
#   'bmi': 37.0,
#   'children': 5,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 4830.63},
#  {'age': 32,
#   'sex': 'female',
#   'bmi': 33.2,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 6128.8},
#  {'age': 19,
#   'sex': 'female',
#   'bmi': 31.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2719.28},
#  {'age': 27,
#   'sex': 'male',
#   'bmi': 18.9,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4827.9},
#  {'age': 63,
#   'sex': 'male',
#   'bmi': 41.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 13405.39},
#  {'age': 49,
#   'sex': 'male',
#   'bmi': 30.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 8116.68},
#  {'age': 18,
#   'sex': 'male',
#   'bmi': 16.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 1694.8},
#  {'age': 35,
#   'sex': 'female',
#   'bmi': 34.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 5246.05},
#  {'age': 24,
#   'sex': 'female',
#   'bmi': 33.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2855.44},
#  {'age': 63,
#   'sex': 'female',
#   'bmi': 37.7,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 48824.45},
#  {'age': 38,
#   'sex': 'male',
#   'bmi': 27.8,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 6455.86},
#  {'age': 54,
#   'sex': 'male',
#   'bmi': 29.2,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 10436.1},
#  {'age': 46,
#   'sex': 'female',
#   'bmi': 28.9,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 8823.28},
#  {'age': 41,
#   'sex': 'female',
#   'bmi': 33.2,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 8538.29},
#  {'age': 58,
#   'sex': 'male',
#   'bmi': 28.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 11735.88},
#  {'age': 18,
#   'sex': 'female',
#   'bmi': 38.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 1631.82},
#  {'age': 22,
#   'sex': 'male',
#   'bmi': 20.0,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4005.42},
#  {'age': 44,
#   'sex': 'female',
#   'bmi': 26.4,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 7419.48},
#  {'age': 44,
#   'sex': 'male',
#   'bmi': 30.7,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 7731.43},
#  {'age': 36,
#   'sex': 'male',
#   'bmi': 41.9,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 43753.34},
#  {'age': 26,
#   'sex': 'female',
#   'bmi': 29.9,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 3981.98},
#  {'age': 30,
#   'sex': 'female',
#   'bmi': 30.9,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 5325.65},
#  {'age': 41,
#   'sex': 'female',
#   'bmi': 32.2,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 6775.96},
#  {'age': 29,
#   'sex': 'female',
#   'bmi': 32.1,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 4922.92},
#  {'age': 61,
#   'sex': 'male',
#   'bmi': 31.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 12557.61},
#  {'age': 36,
#   'sex': 'female',
#   'bmi': 26.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 4883.87},
#  {'age': 25,
#   'sex': 'male',
#   'bmi': 25.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2137.65},
#  {'age': 56,
#   'sex': 'female',
#   'bmi': 26.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 12044.34},
#  {'age': 18,
#   'sex': 'male',
#   'bmi': 34.4,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 1137.47},
#  {'age': 19,
#   'sex': 'male',
#   'bmi': 30.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 1639.56},
#  {'age': 39,
#   'sex': 'female',
#   'bmi': 32.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 5649.72},
#  {'age': 45,
#   'sex': 'female',
#   'bmi': 28.6,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 8516.83},
#  {'age': 51,
#   'sex': 'female',
#   'bmi': 18.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 9644.25},
#  {'age': 64,
#   'sex': 'female',
#   'bmi': 39.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 14901.52},
#  {'age': 19,
#   'sex': 'female',
#   'bmi': 32.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2130.68},
#  {'age': 48,
#   'sex': 'female',
#   'bmi': 32.2,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 8871.15},
#  {'age': 60,
#   'sex': 'female',
#   'bmi': 24.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 13012.21},
#  {'age': 27,
#   'sex': 'female',
#   'bmi': 36.1,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 37133.9},
#  {'age': 46,
#   'sex': 'male',
#   'bmi': 22.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 7147.11},
#  {'age': 28,
#   'sex': 'female',
#   'bmi': 28.9,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4337.74},
#  {'age': 59,
#   'sex': 'male',
#   'bmi': 26.4,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 11743.3},
#  {'age': 35,
#   'sex': 'male',
#   'bmi': 27.7,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 20984.09},
#  {'age': 63,
#   'sex': 'female',
#   'bmi': 31.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 13880.95},
#  {'age': 40,
#   'sex': 'male',
#   'bmi': 41.2,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 6610.11},
#  {'age': 20,
#   'sex': 'male',
#   'bmi': 33.0,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 1980.07},
#  {'age': 40,
#   'sex': 'male',
#   'bmi': 30.9,
#   'children': 4,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 8162.72},
#  {'age': 24,
#   'sex': 'male',
#   'bmi': 28.5,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 3537.7},
#  {'age': 34,
#   'sex': 'female',
#   'bmi': 26.7,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 5002.78},
#  {'age': 45,
#   'sex': 'female',
#   'bmi': 30.9,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 8520.03},
#  {'age': 41,
#   'sex': 'female',
#   'bmi': 37.1,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 7371.77},
#  {'age': 53,
#   'sex': 'female',
#   'bmi': 26.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 10355.64},
#  {'age': 27,
#   'sex': 'male',
#   'bmi': 23.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2483.74},
#  {'age': 26,
#   'sex': 'female',
#   'bmi': 29.9,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 3392.98},
#  {'age': 24,
#   'sex': 'female',
#   'bmi': 23.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 25081.77},
#  {'age': 34,
#   'sex': 'female',
#   'bmi': 33.7,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 5012.47},
#  {'age': 53,
#   'sex': 'female',
#   'bmi': 33.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 10564.88},
#  {'age': 32,
#   'sex': 'male',
#   'bmi': 30.8,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 5253.52},
#  {'age': 19,
#   'sex': 'male',
#   'bmi': 34.8,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 34779.62},
#  {'age': 42,
#   'sex': 'male',
#   'bmi': 24.6,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 19515.54},
#  {'age': 55,
#   'sex': 'male',
#   'bmi': 33.9,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 11987.17},
#  {'age': 28,
#   'sex': 'male',
#   'bmi': 38.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2689.5},
#  {'age': 58,
#   'sex': 'female',
#   'bmi': 41.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 24227.34},
#  {'age': 41,
#   'sex': 'female',
#   'bmi': 31.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 7358.18},
#  {'age': 47,
#   'sex': 'male',
#   'bmi': 25.5,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 9225.26},
#  {'age': 42,
#   'sex': 'female',
#   'bmi': 36.2,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 7443.64},
#  {'age': 59,
#   'sex': 'female',
#   'bmi': 27.8,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 14001.29},
#  {'age': 19,
#   'sex': 'female',
#   'bmi': 17.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 1727.79},
#  {'age': 59,
#   'sex': 'male',
#   'bmi': 27.5,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 12333.83},
#  {'age': 39,
#   'sex': 'male',
#   'bmi': 24.5,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 6710.19},
#  {'age': 40,
#   'sex': 'female',
#   'bmi': 22.2,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 19444.27},
#  {'age': 18,
#   'sex': 'female',
#   'bmi': 26.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 1615.77},
#  {'age': 31,
#   'sex': 'male',
#   'bmi': 38.4,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 4463.21},
#  {'age': 19,
#   'sex': 'male',
#   'bmi': 29.1,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 17352.68},
#  {'age': 44,
#   'sex': 'male',
#   'bmi': 38.1,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 7152.67},
#  {'age': 23,
#   'sex': 'female',
#   'bmi': 36.7,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 38511.63},
#  {'age': 33,
#   'sex': 'female',
#   'bmi': 22.1,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 5354.07},
#  {'age': 55,
#   'sex': 'female',
#   'bmi': 26.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 35160.13},
#  {'age': 40,
#   'sex': 'male',
#   'bmi': 35.3,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 7196.87},
#  {'age': 63,
#   'sex': 'female',
#   'bmi': 27.7,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 29523.17},
#  {'age': 54,
#   'sex': 'male',
#   'bmi': 30.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 24476.48},
#  {'age': 60,
#   'sex': 'female',
#   'bmi': 38.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 12648.7},
#  {'age': 24,
#   'sex': 'male',
#   'bmi': 35.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 1986.93},
#  {'age': 19,
#   'sex': 'male',
#   'bmi': 20.9,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 1832.09},
#  {'age': 29,
#   'sex': 'male',
#   'bmi': 29.0,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4040.56},
#  {'age': 18,
#   'sex': 'male',
#   'bmi': 17.3,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 12829.46},
#  {'age': 63,
#   'sex': 'female',
#   'bmi': 32.2,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 47305.31},
#  {'age': 54,
#   'sex': 'male',
#   'bmi': 34.2,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 44260.75},
#  {'age': 27,
#   'sex': 'male',
#   'bmi': 30.3,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 4260.74},
#  {'age': 50,
#   'sex': 'male',
#   'bmi': 31.8,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 41097.16},
#  {'age': 55,
#   'sex': 'female',
#   'bmi': 25.4,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 13047.33},
#  {'age': 56,
#   'sex': 'male',
#   'bmi': 33.6,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 43921.18},
#  {'age': 38,
#   'sex': 'female',
#   'bmi': 40.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 5400.98},
#  {'age': 51,
#   'sex': 'male',
#   'bmi': 24.4,
#   'children': 4,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 11520.1},
#  {'age': 19,
#   'sex': 'male',
#   'bmi': 31.9,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 33750.29},
#  {'age': 58,
#   'sex': 'female',
#   'bmi': 25.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 11837.16},
#  {'age': 20,
#   'sex': 'female',
#   'bmi': 26.8,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 17085.27},
#  {'age': 52,
#   'sex': 'male',
#   'bmi': 24.3,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 24869.84},
#  {'age': 19,
#   'sex': 'male',
#   'bmi': 37.0,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 36219.41},
#  {'age': 53,
#   'sex': 'female',
#   'bmi': 38.1,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 20463.0},
#  {'age': 46,
#   'sex': 'male',
#   'bmi': 42.4,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 46151.12},
#  {'age': 40,
#   'sex': 'male',
#   'bmi': 19.8,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 17179.52},
#  {'age': 59,
#   'sex': 'female',
#   'bmi': 32.4,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 14590.63},
#  {'age': 45,
#   'sex': 'male',
#   'bmi': 30.2,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 7441.05},
#  {'age': 49,
#   'sex': 'male',
#   'bmi': 25.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 9282.48},
#  {'age': 18,
#   'sex': 'male',
#   'bmi': 29.4,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 1719.44},
#  {'age': 50,
#   'sex': 'male',
#   'bmi': 34.2,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 42856.84},
#  {'age': 41,
#   'sex': 'male',
#   'bmi': 37.1,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 7265.7},
#  {'age': 50,
#   'sex': 'male',
#   'bmi': 27.5,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 9617.66},
#  {'age': 25,
#   'sex': 'male',
#   'bmi': 27.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2523.17},
#  {'age': 47,
#   'sex': 'female',
#   'bmi': 26.6,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 9715.84},
#  {'age': 19,
#   'sex': 'male',
#   'bmi': 20.6,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2803.7},
#  {'age': 22,
#   'sex': 'female',
#   'bmi': 24.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 2150.47},
#  {'age': 59,
#   'sex': 'male',
#   'bmi': 31.8,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 12928.79},
#  {'age': 51,
#   'sex': 'female',
#   'bmi': 21.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 9855.13},
#  {'age': 40,
#   'sex': 'female',
#   'bmi': 28.1,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 22331.57},
#  {'age': 54,
#   'sex': 'male',
#   'bmi': 40.6,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 48549.18},
#  {'age': 30,
#   'sex': 'male',
#   'bmi': 27.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4237.13},
#  {'age': 55,
#   'sex': 'female',
#   'bmi': 32.4,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 11879.1},
#  {'age': 52,
#   'sex': 'female',
#   'bmi': 31.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 9625.92},
#  {'age': 46,
#   'sex': 'male',
#   'bmi': 26.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 7742.11},
#  {'age': 46,
#   'sex': 'female',
#   'bmi': 48.1,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 9432.93},
#  {'age': 63,
#   'sex': 'female',
#   'bmi': 26.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 14256.19},
#  {'age': 59,
#   'sex': 'female',
#   'bmi': 36.8,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 47896.79},
#  {'age': 52,
#   'sex': 'male',
#   'bmi': 26.4,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 25992.82},
#  {'age': 28,
#   'sex': 'female',
#   'bmi': 33.4,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 3172.02},
#  {'age': 29,
#   'sex': 'male',
#   'bmi': 29.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 20277.81},
#  {'age': 25,
#   'sex': 'male',
#   'bmi': 45.5,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 42112.24},
#  {'age': 22,
#   'sex': 'female',
#   'bmi': 28.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2156.75},
#  {'age': 25,
#   'sex': 'male',
#   'bmi': 26.8,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 3906.13},
#  {'age': 18,
#   'sex': 'male',
#   'bmi': 23.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 1704.57},
#  {'age': 19,
#   'sex': 'male',
#   'bmi': 27.7,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 16297.85},
#  {'age': 47,
#   'sex': 'male',
#   'bmi': 25.4,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 21978.68},
#  {'age': 31,
#   'sex': 'male',
#   'bmi': 34.4,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 38746.36},
#  {'age': 48,
#   'sex': 'female',
#   'bmi': 28.9,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 9249.5},
#  {'age': 36,
#   'sex': 'male',
#   'bmi': 27.6,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 6746.74},
#  {'age': 53,
#   'sex': 'female',
#   'bmi': 22.6,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 24873.38},
#  {'age': 56,
#   'sex': 'female',
#   'bmi': 37.5,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 12265.51},
#  {'age': 28,
#   'sex': 'female',
#   'bmi': 33.0,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 4349.46},
#  {'age': 57,
#   'sex': 'female',
#   'bmi': 38.0,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 12646.21},
#  {'age': 29,
#   'sex': 'male',
#   'bmi': 33.3,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 19442.35},
#  {'age': 28,
#   'sex': 'female',
#   'bmi': 27.5,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 20177.67},
#  {'age': 30,
#   'sex': 'female',
#   'bmi': 33.3,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 4151.03},
#  {'age': 58,
#   'sex': 'male',
#   'bmi': 34.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 11944.59},
#  {'age': 41,
#   'sex': 'female',
#   'bmi': 33.1,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 7749.16},
#  {'age': 50,
#   'sex': 'male',
#   'bmi': 26.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 8444.47},
#  {'age': 19,
#   'sex': 'female',
#   'bmi': 24.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 1737.38},
#  {'age': 43,
#   'sex': 'male',
#   'bmi': 36.0,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 42124.52},
#  {'age': 49,
#   'sex': 'male',
#   'bmi': 35.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 8124.41},
#  {'age': 27,
#   'sex': 'female',
#   'bmi': 31.4,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 34838.87},
#  {'age': 52,
#   'sex': 'male',
#   'bmi': 33.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 9722.77},
#  {'age': 50,
#   'sex': 'male',
#   'bmi': 32.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 8835.26},
#  {'age': 54,
#   'sex': 'male',
#   'bmi': 32.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 10435.07},
#  {'age': 44,
#   'sex': 'female',
#   'bmi': 27.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 7421.19},
#  {'age': 32,
#   'sex': 'male',
#   'bmi': 37.3,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4667.61},
#  {'age': 34,
#   'sex': 'male',
#   'bmi': 25.3,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 4894.75},
#  {'age': 26,
#   'sex': 'female',
#   'bmi': 29.6,
#   'children': 4,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 24671.66},
#  {'age': 34,
#   'sex': 'male',
#   'bmi': 30.8,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 35491.64},
#  {'age': 57,
#   'sex': 'male',
#   'bmi': 40.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 11566.3},
#  {'age': 29,
#   'sex': 'male',
#   'bmi': 27.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 2866.09},
#  {'age': 40,
#   'sex': 'male',
#   'bmi': 34.1,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 6600.21},
#  {'age': 27,
#   'sex': 'female',
#   'bmi': 23.2,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 3561.89},
#  {'age': 45,
#   'sex': 'male',
#   'bmi': 36.5,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 42760.5},
#  {'age': 64,
#   'sex': 'female',
#   'bmi': 33.8,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 47928.03},
#  {'age': 52,
#   'sex': 'male',
#   'bmi': 36.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 9144.57},
#  {'age': 61,
#   'sex': 'female',
#   'bmi': 36.4,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 48517.56},
#  {'age': 52,
#   'sex': 'male',
#   'bmi': 27.4,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 24393.62},
#  {'age': 61,
#   'sex': 'female',
#   'bmi': 31.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 13429.04},
#  {'age': 56,
#   'sex': 'female',
#   'bmi': 28.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 11658.38},
#  {'age': 43,
#   'sex': 'female',
#   'bmi': 35.7,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 19144.58},
#  {'age': 64,
#   'sex': 'male',
#   'bmi': 34.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 13822.8},
#  {'age': 60,
#   'sex': 'male',
#   'bmi': 25.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 12142.58},
#  {'age': 62,
#   'sex': 'male',
#   'bmi': 27.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 13937.67},
#  {'age': 50,
#   'sex': 'male',
#   'bmi': 32.3,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 41919.1},
#  {'age': 46,
#   'sex': 'female',
#   'bmi': 27.7,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 8232.64},
#  {'age': 24,
#   'sex': 'female',
#   'bmi': 27.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 18955.22},
#  {'age': 62,
#   'sex': 'male',
#   'bmi': 30.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 13352.1},
#  {'age': 60,
#   'sex': 'female',
#   'bmi': 27.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 13217.09},
#  {'age': 63,
#   'sex': 'male',
#   'bmi': 36.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 13981.85},
#  {'age': 49,
#   'sex': 'female',
#   'bmi': 41.5,
#   'children': 4,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 10977.21},
#  {'age': 34,
#   'sex': 'female',
#   'bmi': 29.3,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 6184.3},
#  {'age': 33,
#   'sex': 'male',
#   'bmi': 35.8,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 4890.0},
#  {'age': 46,
#   'sex': 'male',
#   'bmi': 33.3,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 8334.46},
#  {'age': 36,
#   'sex': 'female',
#   'bmi': 29.9,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 5478.04},
#  {'age': 19,
#   'sex': 'male',
#   'bmi': 27.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 1635.73},
#  {'age': 57,
#   'sex': 'female',
#   'bmi': 23.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 11830.61},
#  {'age': 50,
#   'sex': 'female',
#   'bmi': 25.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 8932.08},
#  {'age': 30,
#   'sex': 'female',
#   'bmi': 27.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 3554.2},
#  {'age': 33,
#   'sex': 'male',
#   'bmi': 35.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 12404.88},
#  {'age': 18,
#   'sex': 'female',
#   'bmi': 38.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 14133.04},
#  {'age': 46,
#   'sex': 'male',
#   'bmi': 27.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 24603.05},
#  {'age': 46,
#   'sex': 'male',
#   'bmi': 43.9,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 8944.12},
#  {'age': 47,
#   'sex': 'male',
#   'bmi': 29.8,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 9620.33},
#  {'age': 23,
#   'sex': 'male',
#   'bmi': 41.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 1837.28},
#  {'age': 18,
#   'sex': 'female',
#   'bmi': 20.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 1607.51},
#  {'age': 48,
#   'sex': 'female',
#   'bmi': 32.3,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 10043.25},
#  {'age': 35,
#   'sex': 'male',
#   'bmi': 30.5,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 4751.07},
#  {'age': 19,
#   'sex': 'female',
#   'bmi': 21.7,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 13844.51},
#  {'age': 21,
#   'sex': 'female',
#   'bmi': 26.4,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 2597.78},
#  {'age': 21,
#   'sex': 'female',
#   'bmi': 21.9,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 3180.51},
#  {'age': 49,
#   'sex': 'female',
#   'bmi': 30.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 9778.35},
#  {'age': 56,
#   'sex': 'female',
#   'bmi': 32.3,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 13430.27},
#  {'age': 42,
#   'sex': 'female',
#   'bmi': 25.0,
#   'children': 2,
# ...
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 6653.79},
#  {'age': 41,
#   'sex': 'male',
#   'bmi': 28.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 6282.24},
#  {'age': 37,
#   'sex': 'female',
#   'bmi': 29.5,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 6311.95},
#  {'age': 22,
#   'sex': 'male',
#   'bmi': 34.8,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 3443.06},
#  {'age': 23,
#   'sex': 'male',
#   'bmi': 27.4,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2789.06},
#  {'age': 21,
#   'sex': 'female',
#   'bmi': 22.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 2585.85},
#  {'age': 51,
#   'sex': 'female',
#   'bmi': 37.1,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 46255.11},
#  {'age': 25,
#   'sex': 'male',
#   'bmi': 26.7,
#   'children': 4,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 4877.98},
#  {'age': 32,
#   'sex': 'male',
#   'bmi': 28.9,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 19719.69},
#  {'age': 57,
#   'sex': 'male',
#   'bmi': 29.0,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 27218.44},
#  {'age': 36,
#   'sex': 'female',
#   'bmi': 30.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 5272.18},
#  {'age': 22,
#   'sex': 'male',
#   'bmi': 39.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 1682.6},
#  {'age': 57,
#   'sex': 'male',
#   'bmi': 33.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 11945.13},
#  {'age': 64,
#   'sex': 'female',
#   'bmi': 26.9,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 29330.98},
#  {'age': 36,
#   'sex': 'female',
#   'bmi': 29.0,
#   'children': 4,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 7243.81},
#  {'age': 54,
#   'sex': 'male',
#   'bmi': 24.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 10422.92},
#  {'age': 47,
#   'sex': 'male',
#   'bmi': 38.9,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 44202.65},
#  {'age': 62,
#   'sex': 'male',
#   'bmi': 32.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 13555.0},
#  {'age': 61,
#   'sex': 'female',
#   'bmi': 44.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 13063.88},
#  {'age': 43,
#   'sex': 'female',
#   'bmi': 20.0,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 19798.05},
#  {'age': 19,
#   'sex': 'male',
#   'bmi': 25.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2221.56},
#  {'age': 18,
#   'sex': 'female',
#   'bmi': 40.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 1634.57},
#  {'age': 19,
#   'sex': 'female',
#   'bmi': 22.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2117.34},
#  {'age': 49,
#   'sex': 'male',
#   'bmi': 22.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 8688.86},
#  {'age': 60,
#   'sex': 'male',
#   'bmi': 40.9,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 48673.56},
#  {'age': 26,
#   'sex': 'male',
#   'bmi': 27.3,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4661.29},
#  {'age': 49,
#   'sex': 'male',
#   'bmi': 36.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 8125.78},
#  {'age': 60,
#   'sex': 'female',
#   'bmi': 35.1,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 12644.59},
#  {'age': 26,
#   'sex': 'female',
#   'bmi': 29.4,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4564.19},
#  {'age': 27,
#   'sex': 'male',
#   'bmi': 32.6,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4846.92},
#  {'age': 44,
#   'sex': 'female',
#   'bmi': 32.3,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 7633.72},
#  {'age': 63,
#   'sex': 'male',
#   'bmi': 39.8,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 15170.07},
#  {'age': 32,
#   'sex': 'female',
#   'bmi': 24.6,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 17496.31},
#  {'age': 22,
#   'sex': 'male',
#   'bmi': 28.3,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2639.04},
#  {'age': 18,
#   'sex': 'male',
#   'bmi': 31.7,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 33732.69},
#  {'age': 59,
#   'sex': 'female',
#   'bmi': 26.7,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 14382.71},
#  {'age': 44,
#   'sex': 'female',
#   'bmi': 27.5,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 7626.99},
#  {'age': 33,
#   'sex': 'male',
#   'bmi': 24.6,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 5257.51},
#  {'age': 24,
#   'sex': 'female',
#   'bmi': 34.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2473.33},
#  {'age': 43,
#   'sex': 'female',
#   'bmi': 26.9,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 21774.32},
#  {'age': 45,
#   'sex': 'male',
#   'bmi': 22.9,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 35069.37},
#  {'age': 61,
#   'sex': 'female',
#   'bmi': 28.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 13041.92},
#  {'age': 35,
#   'sex': 'female',
#   'bmi': 34.2,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 5245.23},
#  {'age': 62,
#   'sex': 'female',
#   'bmi': 25.0,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 13451.12},
#  {'age': 62,
#   'sex': 'female',
#   'bmi': 33.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 13462.52},
#  {'age': 38,
#   'sex': 'male',
#   'bmi': 31.0,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 5488.26},
#  {'age': 34,
#   'sex': 'male',
#   'bmi': 35.8,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 4320.41},
#  {'age': 43,
#   'sex': 'male',
#   'bmi': 23.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 6250.44},
#  {'age': 50,
#   'sex': 'male',
#   'bmi': 32.1,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 25333.33},
#  {'age': 19,
#   'sex': 'female',
#   'bmi': 23.4,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 2913.57},
#  {'age': 57,
#   'sex': 'female',
#   'bmi': 20.1,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 12032.33},
#  {'age': 62,
#   'sex': 'female',
#   'bmi': 39.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 13470.8},
#  {'age': 41,
#   'sex': 'male',
#   'bmi': 34.2,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 6289.75},
#  {'age': 26,
#   'sex': 'male',
#   'bmi': 46.5,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2927.06},
#  {'age': 39,
#   'sex': 'female',
#   'bmi': 32.5,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 6238.3},
#  {'age': 46,
#   'sex': 'male',
#   'bmi': 25.8,
#   'children': 5,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 10096.97},
#  {'age': 45,
#   'sex': 'female',
#   'bmi': 35.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 7348.14},
#  {'age': 32,
#   'sex': 'male',
#   'bmi': 37.2,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 4673.39},
#  {'age': 59,
#   'sex': 'female',
#   'bmi': 27.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 12233.83},
#  {'age': 44,
#   'sex': 'male',
#   'bmi': 29.7,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 32108.66},
#  {'age': 39,
#   'sex': 'female',
#   'bmi': 24.2,
#   'children': 5,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 8965.8},
#  {'age': 18,
#   'sex': 'male',
#   'bmi': 26.2,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2304.0},
#  {'age': 53,
#   'sex': 'male',
#   'bmi': 29.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 9487.64},
#  {'age': 18,
#   'sex': 'male',
#   'bmi': 23.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 1121.87},
#  {'age': 50,
#   'sex': 'female',
#   'bmi': 46.1,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 9549.57},
#  {'age': 18,
#   'sex': 'female',
#   'bmi': 40.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 2217.47},
#  {'age': 19,
#   'sex': 'male',
#   'bmi': 22.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 1628.47},
#  {'age': 62,
#   'sex': 'male',
#   'bmi': 39.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 12982.87},
#  {'age': 56,
#   'sex': 'female',
#   'bmi': 35.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 11674.13},
#  {'age': 42,
#   'sex': 'male',
#   'bmi': 35.8,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 7160.09},
#  {'age': 37,
#   'sex': 'male',
#   'bmi': 34.2,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 39047.29},
#  {'age': 42,
#   'sex': 'male',
#   'bmi': 31.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 6358.78},
#  {'age': 25,
#   'sex': 'male',
#   'bmi': 29.7,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 19933.46},
#  {'age': 57,
#   'sex': 'male',
#   'bmi': 18.3,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 11534.87},
#  {'age': 51,
#   'sex': 'male',
#   'bmi': 42.9,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 47462.89},
#  {'age': 30,
#   'sex': 'female',
#   'bmi': 28.4,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 4527.18},
#  {'age': 44,
#   'sex': 'male',
#   'bmi': 30.2,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 38998.55},
#  {'age': 34,
#   'sex': 'male',
#   'bmi': 27.8,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 20009.63},
#  {'age': 31,
#   'sex': 'male',
#   'bmi': 39.5,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 3875.73},
#  {'age': 54,
#   'sex': 'male',
#   'bmi': 30.8,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'southeast',
#   'expenses': 41999.52},
#  {'age': 24,
#   'sex': 'male',
#   'bmi': 26.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 12609.89},
#  {'age': 43,
#   'sex': 'male',
#   'bmi': 35.0,
#   'children': 1,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 41034.22},
#  {'age': 48,
#   'sex': 'male',
#   'bmi': 36.7,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 28468.92},
#  {'age': 19,
#   'sex': 'female',
#   'bmi': 39.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2730.11},
#  {'age': 29,
#   'sex': 'female',
#   'bmi': 25.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 3353.28},
#  {'age': 63,
#   'sex': 'female',
#   'bmi': 35.2,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 14474.68},
#  {'age': 46,
#   'sex': 'male',
#   'bmi': 24.8,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 9500.57},
#  {'age': 52,
#   'sex': 'male',
#   'bmi': 36.8,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 26467.1},
#  {'age': 35,
#   'sex': 'male',
#   'bmi': 27.1,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 4746.34},
#  {'age': 51,
#   'sex': 'male',
#   'bmi': 24.8,
#   'children': 2,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 23967.38},
#  {'age': 44,
#   'sex': 'male',
#   'bmi': 25.4,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 7518.03},
#  {'age': 21,
#   'sex': 'male',
#   'bmi': 25.7,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 3279.87},
#  {'age': 39,
#   'sex': 'female',
#   'bmi': 34.3,
#   'children': 5,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 8596.83},
#  {'age': 50,
#   'sex': 'female',
#   'bmi': 28.2,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 10702.64},
#  {'age': 34,
#   'sex': 'female',
#   'bmi': 23.6,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4992.38},
#  {'age': 22,
#   'sex': 'female',
#   'bmi': 20.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 2527.82},
#  {'age': 19,
#   'sex': 'female',
#   'bmi': 40.5,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 1759.34},
#  {'age': 26,
#   'sex': 'male',
#   'bmi': 35.4,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2322.62},
#  {'age': 29,
#   'sex': 'male',
#   'bmi': 22.9,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 16138.76},
#  {'age': 48,
#   'sex': 'male',
#   'bmi': 40.2,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 7804.16},
#  {'age': 26,
#   'sex': 'male',
#   'bmi': 29.2,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 2902.91},
#  {'age': 45,
#   'sex': 'female',
#   'bmi': 40.0,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 9704.67},
#  {'age': 36,
#   'sex': 'female',
#   'bmi': 29.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 4889.04},
#  {'age': 54,
#   'sex': 'male',
#   'bmi': 25.5,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 25517.11},
#  {'age': 34,
#   'sex': 'male',
#   'bmi': 21.4,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4500.34},
#  {'age': 31,
#   'sex': 'male',
#   'bmi': 25.9,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 19199.94},
#  {'age': 27,
#   'sex': 'female',
#   'bmi': 30.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 16796.41},
#  {'age': 20,
#   'sex': 'male',
#   'bmi': 30.1,
#   'children': 5,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4915.06},
#  {'age': 44,
#   'sex': 'female',
#   'bmi': 25.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 7624.63},
#  {'age': 43,
#   'sex': 'male',
#   'bmi': 30.1,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 8410.05},
#  {'age': 45,
#   'sex': 'female',
#   'bmi': 27.6,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 28340.19},
#  {'age': 34,
#   'sex': 'male',
#   'bmi': 34.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 4518.83},
#  {'age': 24,
#   'sex': 'female',
#   'bmi': 20.5,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'northeast',
#   'expenses': 14571.89},
#  {'age': 26,
#   'sex': 'female',
#   'bmi': 19.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 3378.91},
#  {'age': 38,
#   'sex': 'female',
#   'bmi': 27.8,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 7144.86},
#  {'age': 50,
#   'sex': 'female',
#   'bmi': 31.6,
#   'children': 2,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 10118.42},
#  {'age': 38,
#   'sex': 'male',
#   'bmi': 28.3,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 5484.47},
#  {'age': 27,
#   'sex': 'female',
#   'bmi': 20.0,
#   'children': 3,
#   'smoker': 'yes',
#   'region': 'northwest',
#   'expenses': 16420.49},
#  {'age': 39,
#   'sex': 'female',
#   'bmi': 23.3,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 7986.48},
#  {'age': 39,
#   'sex': 'female',
#   'bmi': 34.1,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southwest',
#   'expenses': 7418.52},
#  {'age': 63,
#   'sex': 'female',
#   'bmi': 36.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 13887.97},
#  {'age': 33,
#   'sex': 'female',
#   'bmi': 36.3,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'northeast',
#   'expenses': 6551.75},
#  {'age': 36,
#   'sex': 'female',
#   'bmi': 26.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 5267.82},
#  ...]

# %%
#creating database settings

DB_NAME = "insurance" # Specifiy a Database Name

# Connection URL
CONNECTION_URL = "mongodb+srv://abhi:mongo123@cluster1.m3wowhd.mongodb.net/?retryWrites=true&w=majority"

# Establish a connection with mongoDB
client = pymongo.MongoClient(CONNECTION_URL)

# Create a DB
dataBase = client[DB_NAME]

# Create a Collection Name
COLLECTION_NAME = "insurance_data"
collection = dataBase[COLLECTION_NAME]

# %%
# insert above records in the collection
rec = collection.insert_many(data)
print('Done.')
# Out:
# Done.

# %%
# Lets Verify all the record at once present in the record with all the fields
all_record = collection.find()

for idx, record in enumerate(all_record):
    print(f"{idx}: {record}")
# Out:
# 0: {'_id': ObjectId('64e5a010ab40cfa92024883f'), 'age': 19, 'sex': 'female', 'bmi': 27.9, 'children': 0, 'smoker': 'yes', 'region': 'southwest', 'expenses': 16884.92}
# 1: {'_id': ObjectId('64e5a010ab40cfa920248840'), 'age': 18, 'sex': 'male', 'bmi': 33.8, 'children': 1, 'smoker': 'no', 'region': 'southeast', 'expenses': 1725.55}
# 2: {'_id': ObjectId('64e5a010ab40cfa920248841'), 'age': 28, 'sex': 'male', 'bmi': 33.0, 'children': 3, 'smoker': 'no', 'region': 'southeast', 'expenses': 4449.46}
# 3: {'_id': ObjectId('64e5a010ab40cfa920248842'), 'age': 33, 'sex': 'male', 'bmi': 22.7, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 21984.47}
# 4: {'_id': ObjectId('64e5a010ab40cfa920248843'), 'age': 32, 'sex': 'male', 'bmi': 28.9, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 3866.86}
# 5: {'_id': ObjectId('64e5a010ab40cfa920248844'), 'age': 31, 'sex': 'female', 'bmi': 25.7, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 3756.62}
# 6: {'_id': ObjectId('64e5a010ab40cfa920248845'), 'age': 46, 'sex': 'female', 'bmi': 33.4, 'children': 1, 'smoker': 'no', 'region': 'southeast', 'expenses': 8240.59}
# 7: {'_id': ObjectId('64e5a010ab40cfa920248846'), 'age': 37, 'sex': 'female', 'bmi': 27.7, 'children': 3, 'smoker': 'no', 'region': 'northwest', 'expenses': 7281.51}
# 8: {'_id': ObjectId('64e5a010ab40cfa920248847'), 'age': 37, 'sex': 'male', 'bmi': 29.8, 'children': 2, 'smoker': 'no', 'region': 'northeast', 'expenses': 6406.41}
# 9: {'_id': ObjectId('64e5a010ab40cfa920248848'), 'age': 60, 'sex': 'female', 'bmi': 25.8, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 28923.14}
# 10: {'_id': ObjectId('64e5a010ab40cfa920248849'), 'age': 25, 'sex': 'male', 'bmi': 26.2, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 2721.32}
# 11: {'_id': ObjectId('64e5a010ab40cfa92024884a'), 'age': 62, 'sex': 'female', 'bmi': 26.3, 'children': 0, 'smoker': 'yes', 'region': 'southeast', 'expenses': 27808.73}
# 12: {'_id': ObjectId('64e5a010ab40cfa92024884b'), 'age': 23, 'sex': 'male', 'bmi': 34.4, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 1826.84}
# 13: {'_id': ObjectId('64e5a010ab40cfa92024884c'), 'age': 56, 'sex': 'female', 'bmi': 39.8, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 11090.72}
# 14: {'_id': ObjectId('64e5a010ab40cfa92024884d'), 'age': 27, 'sex': 'male', 'bmi': 42.1, 'children': 0, 'smoker': 'yes', 'region': 'southeast', 'expenses': 39611.76}
# 15: {'_id': ObjectId('64e5a010ab40cfa92024884e'), 'age': 19, 'sex': 'male', 'bmi': 24.6, 'children': 1, 'smoker': 'no', 'region': 'southwest', 'expenses': 1837.24}
# 16: {'_id': ObjectId('64e5a010ab40cfa92024884f'), 'age': 52, 'sex': 'female', 'bmi': 30.8, 'children': 1, 'smoker': 'no', 'region': 'northeast', 'expenses': 10797.34}
# 17: {'_id': ObjectId('64e5a010ab40cfa920248850'), 'age': 23, 'sex': 'male', 'bmi': 23.8, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 2395.17}
# 18: {'_id': ObjectId('64e5a010ab40cfa920248851'), 'age': 56, 'sex': 'male', 'bmi': 40.3, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 10602.39}
# 19: {'_id': ObjectId('64e5a010ab40cfa920248852'), 'age': 30, 'sex': 'male', 'bmi': 35.3, 'children': 0, 'smoker': 'yes', 'region': 'southwest', 'expenses': 36837.47}
# 20: {'_id': ObjectId('64e5a010ab40cfa920248853'), 'age': 60, 'sex': 'female', 'bmi': 36.0, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 13228.85}
# 21: {'_id': ObjectId('64e5a010ab40cfa920248854'), 'age': 30, 'sex': 'female', 'bmi': 32.4, 'children': 1, 'smoker': 'no', 'region': 'southwest', 'expenses': 4149.74}
# 22: {'_id': ObjectId('64e5a010ab40cfa920248855'), 'age': 18, 'sex': 'male', 'bmi': 34.1, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 1137.01}
# 23: {'_id': ObjectId('64e5a010ab40cfa920248856'), 'age': 34, 'sex': 'female', 'bmi': 31.9, 'children': 1, 'smoker': 'yes', 'region': 'northeast', 'expenses': 37701.88}
# 24: {'_id': ObjectId('64e5a010ab40cfa920248857'), 'age': 37, 'sex': 'male', 'bmi': 28.0, 'children': 2, 'smoker': 'no', 'region': 'northwest', 'expenses': 6203.9}
# 25: {'_id': ObjectId('64e5a010ab40cfa920248858'), 'age': 59, 'sex': 'female', 'bmi': 27.7, 'children': 3, 'smoker': 'no', 'region': 'southeast', 'expenses': 14001.13}
# 26: {'_id': ObjectId('64e5a010ab40cfa920248859'), 'age': 63, 'sex': 'female', 'bmi': 23.1, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 14451.84}
# 27: {'_id': ObjectId('64e5a010ab40cfa92024885a'), 'age': 55, 'sex': 'female', 'bmi': 32.8, 'children': 2, 'smoker': 'no', 'region': 'northwest', 'expenses': 12268.63}
# 28: {'_id': ObjectId('64e5a010ab40cfa92024885b'), 'age': 23, 'sex': 'male', 'bmi': 17.4, 'children': 1, 'smoker': 'no', 'region': 'northwest', 'expenses': 2775.19}
# 29: {'_id': ObjectId('64e5a010ab40cfa92024885c'), 'age': 31, 'sex': 'male', 'bmi': 36.3, 'children': 2, 'smoker': 'yes', 'region': 'southwest', 'expenses': 38711.0}
# 30: {'_id': ObjectId('64e5a010ab40cfa92024885d'), 'age': 22, 'sex': 'male', 'bmi': 35.6, 'children': 0, 'smoker': 'yes', 'region': 'southwest', 'expenses': 35585.58}
# 31: {'_id': ObjectId('64e5a010ab40cfa92024885e'), 'age': 18, 'sex': 'female', 'bmi': 26.3, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 2198.19}
# 32: {'_id': ObjectId('64e5a010ab40cfa92024885f'), 'age': 19, 'sex': 'female', 'bmi': 28.6, 'children': 5, 'smoker': 'no', 'region': 'southwest', 'expenses': 4687.8}
# 33: {'_id': ObjectId('64e5a010ab40cfa920248860'), 'age': 63, 'sex': 'male', 'bmi': 28.3, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 13770.1}
# 34: {'_id': ObjectId('64e5a010ab40cfa920248861'), 'age': 28, 'sex': 'male', 'bmi': 36.4, 'children': 1, 'smoker': 'yes', 'region': 'southwest', 'expenses': 51194.56}
# 35: {'_id': ObjectId('64e5a010ab40cfa920248862'), 'age': 19, 'sex': 'male', 'bmi': 20.4, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 1625.43}
# 36: {'_id': ObjectId('64e5a010ab40cfa920248863'), 'age': 62, 'sex': 'female', 'bmi': 33.0, 'children': 3, 'smoker': 'no', 'region': 'northwest', 'expenses': 15612.19}
# 37: {'_id': ObjectId('64e5a010ab40cfa920248864'), 'age': 26, 'sex': 'male', 'bmi': 20.8, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 2302.3}
# 38: {'_id': ObjectId('64e5a010ab40cfa920248865'), 'age': 35, 'sex': 'male', 'bmi': 36.7, 'children': 1, 'smoker': 'yes', 'region': 'northeast', 'expenses': 39774.28}
# 39: {'_id': ObjectId('64e5a010ab40cfa920248866'), 'age': 60, 'sex': 'male', 'bmi': 39.9, 'children': 0, 'smoker': 'yes', 'region': 'southwest', 'expenses': 48173.36}
# 40: {'_id': ObjectId('64e5a010ab40cfa920248867'), 'age': 24, 'sex': 'female', 'bmi': 26.6, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 3046.06}
# 41: {'_id': ObjectId('64e5a010ab40cfa920248868'), 'age': 31, 'sex': 'female', 'bmi': 36.6, 'children': 2, 'smoker': 'no', 'region': 'southeast', 'expenses': 4949.76}
# 42: {'_id': ObjectId('64e5a010ab40cfa920248869'), 'age': 41, 'sex': 'male', 'bmi': 21.8, 'children': 1, 'smoker': 'no', 'region': 'southeast', 'expenses': 6272.48}
# 43: {'_id': ObjectId('64e5a010ab40cfa92024886a'), 'age': 37, 'sex': 'female', 'bmi': 30.8, 'children': 2, 'smoker': 'no', 'region': 'southeast', 'expenses': 6313.76}
# 44: {'_id': ObjectId('64e5a010ab40cfa92024886b'), 'age': 38, 'sex': 'male', 'bmi': 37.1, 'children': 1, 'smoker': 'no', 'region': 'northeast', 'expenses': 6079.67}
# 45: {'_id': ObjectId('64e5a010ab40cfa92024886c'), 'age': 55, 'sex': 'male', 'bmi': 37.3, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 20630.28}
# 46: {'_id': ObjectId('64e5a010ab40cfa92024886d'), 'age': 18, 'sex': 'female', 'bmi': 38.7, 'children': 2, 'smoker': 'no', 'region': 'northeast', 'expenses': 3393.36}
# 47: {'_id': ObjectId('64e5a010ab40cfa92024886e'), 'age': 28, 'sex': 'female', 'bmi': 34.8, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 3556.92}
# 48: {'_id': ObjectId('64e5a010ab40cfa92024886f'), 'age': 60, 'sex': 'female', 'bmi': 24.5, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 12629.9}
# 49: {'_id': ObjectId('64e5a010ab40cfa920248870'), 'age': 36, 'sex': 'male', 'bmi': 35.2, 'children': 1, 'smoker': 'yes', 'region': 'southeast', 'expenses': 38709.18}
# 50: {'_id': ObjectId('64e5a010ab40cfa920248871'), 'age': 18, 'sex': 'female', 'bmi': 35.6, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 2211.13}
# 51: {'_id': ObjectId('64e5a010ab40cfa920248872'), 'age': 21, 'sex': 'female', 'bmi': 33.6, 'children': 2, 'smoker': 'no', 'region': 'northwest', 'expenses': 3579.83}
# 52: {'_id': ObjectId('64e5a010ab40cfa920248873'), 'age': 48, 'sex': 'male', 'bmi': 28.0, 'children': 1, 'smoker': 'yes', 'region': 'southwest', 'expenses': 23568.27}
# 53: {'_id': ObjectId('64e5a010ab40cfa920248874'), 'age': 36, 'sex': 'male', 'bmi': 34.4, 'children': 0, 'smoker': 'yes', 'region': 'southeast', 'expenses': 37742.58}
# 54: {'_id': ObjectId('64e5a010ab40cfa920248875'), 'age': 40, 'sex': 'female', 'bmi': 28.7, 'children': 3, 'smoker': 'no', 'region': 'northwest', 'expenses': 8059.68}
# 55: {'_id': ObjectId('64e5a010ab40cfa920248876'), 'age': 58, 'sex': 'male', 'bmi': 37.0, 'children': 2, 'smoker': 'yes', 'region': 'northwest', 'expenses': 47496.49}
# 56: {'_id': ObjectId('64e5a010ab40cfa920248877'), 'age': 58, 'sex': 'female', 'bmi': 31.8, 'children': 2, 'smoker': 'no', 'region': 'northeast', 'expenses': 13607.37}
# 57: {'_id': ObjectId('64e5a010ab40cfa920248878'), 'age': 18, 'sex': 'male', 'bmi': 31.7, 'children': 2, 'smoker': 'yes', 'region': 'southeast', 'expenses': 34303.17}
# 58: {'_id': ObjectId('64e5a010ab40cfa920248879'), 'age': 53, 'sex': 'female', 'bmi': 22.9, 'children': 1, 'smoker': 'yes', 'region': 'southeast', 'expenses': 23244.79}
# 59: {'_id': ObjectId('64e5a010ab40cfa92024887a'), 'age': 34, 'sex': 'female', 'bmi': 37.3, 'children': 2, 'smoker': 'no', 'region': 'northwest', 'expenses': 5989.52}
# 60: {'_id': ObjectId('64e5a010ab40cfa92024887b'), 'age': 43, 'sex': 'male', 'bmi': 27.4, 'children': 3, 'smoker': 'no', 'region': 'northeast', 'expenses': 8606.22}
# 61: {'_id': ObjectId('64e5a010ab40cfa92024887c'), 'age': 25, 'sex': 'male', 'bmi': 33.7, 'children': 4, 'smoker': 'no', 'region': 'southeast', 'expenses': 4504.66}
# 62: {'_id': ObjectId('64e5a010ab40cfa92024887d'), 'age': 64, 'sex': 'male', 'bmi': 24.7, 'children': 1, 'smoker': 'no', 'region': 'northwest', 'expenses': 30166.62}
# 63: {'_id': ObjectId('64e5a010ab40cfa92024887e'), 'age': 28, 'sex': 'female', 'bmi': 25.9, 'children': 1, 'smoker': 'no', 'region': 'northwest', 'expenses': 4133.64}
# 64: {'_id': ObjectId('64e5a010ab40cfa92024887f'), 'age': 20, 'sex': 'female', 'bmi': 22.4, 'children': 0, 'smoker': 'yes', 'region': 'northwest', 'expenses': 14711.74}
# 65: {'_id': ObjectId('64e5a010ab40cfa920248880'), 'age': 19, 'sex': 'female', 'bmi': 28.9, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 1743.21}
# 66: {'_id': ObjectId('64e5a010ab40cfa920248881'), 'age': 61, 'sex': 'female', 'bmi': 39.1, 'children': 2, 'smoker': 'no', 'region': 'southwest', 'expenses': 14235.07}
# 67: {'_id': ObjectId('64e5a010ab40cfa920248882'), 'age': 40, 'sex': 'male', 'bmi': 26.3, 'children': 1, 'smoker': 'no', 'region': 'northwest', 'expenses': 6389.38}
# 68: {'_id': ObjectId('64e5a010ab40cfa920248883'), 'age': 40, 'sex': 'female', 'bmi': 36.2, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 5920.1}
# 69: {'_id': ObjectId('64e5a010ab40cfa920248884'), 'age': 28, 'sex': 'male', 'bmi': 24.0, 'children': 3, 'smoker': 'yes', 'region': 'southeast', 'expenses': 17663.14}
# 70: {'_id': ObjectId('64e5a010ab40cfa920248885'), 'age': 27, 'sex': 'female', 'bmi': 24.8, 'children': 0, 'smoker': 'yes', 'region': 'southeast', 'expenses': 16577.78}
# 71: {'_id': ObjectId('64e5a010ab40cfa920248886'), 'age': 31, 'sex': 'male', 'bmi': 28.5, 'children': 5, 'smoker': 'no', 'region': 'northeast', 'expenses': 6799.46}
# 72: {'_id': ObjectId('64e5a010ab40cfa920248887'), 'age': 53, 'sex': 'female', 'bmi': 28.1, 'children': 3, 'smoker': 'no', 'region': 'southwest', 'expenses': 11741.73}
# 73: {'_id': ObjectId('64e5a010ab40cfa920248888'), 'age': 58, 'sex': 'male', 'bmi': 32.0, 'children': 1, 'smoker': 'no', 'region': 'southeast', 'expenses': 11946.63}
# 74: {'_id': ObjectId('64e5a010ab40cfa920248889'), 'age': 44, 'sex': 'male', 'bmi': 27.4, 'children': 2, 'smoker': 'no', 'region': 'southwest', 'expenses': 7726.85}
# 75: {'_id': ObjectId('64e5a010ab40cfa92024888a'), 'age': 57, 'sex': 'male', 'bmi': 34.0, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 11356.66}
# 76: {'_id': ObjectId('64e5a010ab40cfa92024888b'), 'age': 29, 'sex': 'female', 'bmi': 29.6, 'children': 1, 'smoker': 'no', 'region': 'southeast', 'expenses': 3947.41}
# 77: {'_id': ObjectId('64e5a010ab40cfa92024888c'), 'age': 21, 'sex': 'male', 'bmi': 35.5, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 1532.47}
# 78: {'_id': ObjectId('64e5a010ab40cfa92024888d'), 'age': 22, 'sex': 'female', 'bmi': 39.8, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 2755.02}
# 79: {'_id': ObjectId('64e5a010ab40cfa92024888e'), 'age': 41, 'sex': 'female', 'bmi': 33.0, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 6571.02}
# 80: {'_id': ObjectId('64e5a010ab40cfa92024888f'), 'age': 31, 'sex': 'male', 'bmi': 26.9, 'children': 1, 'smoker': 'no', 'region': 'northeast', 'expenses': 4441.21}
# 81: {'_id': ObjectId('64e5a010ab40cfa920248890'), 'age': 45, 'sex': 'female', 'bmi': 38.3, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 7935.29}
# 82: {'_id': ObjectId('64e5a010ab40cfa920248891'), 'age': 22, 'sex': 'male', 'bmi': 37.6, 'children': 1, 'smoker': 'yes', 'region': 'southeast', 'expenses': 37165.16}
# 83: {'_id': ObjectId('64e5a010ab40cfa920248892'), 'age': 48, 'sex': 'female', 'bmi': 41.2, 'children': 4, 'smoker': 'no', 'region': 'northwest', 'expenses': 11033.66}
# 84: {'_id': ObjectId('64e5a010ab40cfa920248893'), 'age': 37, 'sex': 'female', 'bmi': 34.8, 'children': 2, 'smoker': 'yes', 'region': 'southwest', 'expenses': 39836.52}
# 85: {'_id': ObjectId('64e5a010ab40cfa920248894'), 'age': 45, 'sex': 'male', 'bmi': 22.9, 'children': 2, 'smoker': 'yes', 'region': 'northwest', 'expenses': 21098.55}
# 86: {'_id': ObjectId('64e5a010ab40cfa920248895'), 'age': 57, 'sex': 'female', 'bmi': 31.2, 'children': 0, 'smoker': 'yes', 'region': 'northwest', 'expenses': 43578.94}
# 87: {'_id': ObjectId('64e5a010ab40cfa920248896'), 'age': 56, 'sex': 'female', 'bmi': 27.2, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 11073.18}
# 88: {'_id': ObjectId('64e5a010ab40cfa920248897'), 'age': 46, 'sex': 'female', 'bmi': 27.7, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 8026.67}
# 89: {'_id': ObjectId('64e5a010ab40cfa920248898'), 'age': 55, 'sex': 'female', 'bmi': 27.0, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 11082.58}
# 90: {'_id': ObjectId('64e5a010ab40cfa920248899'), 'age': 21, 'sex': 'female', 'bmi': 39.5, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 2026.97}
# 91: {'_id': ObjectId('64e5a010ab40cfa92024889a'), 'age': 53, 'sex': 'female', 'bmi': 24.8, 'children': 1, 'smoker': 'no', 'region': 'northwest', 'expenses': 10942.13}
# 92: {'_id': ObjectId('64e5a010ab40cfa92024889b'), 'age': 59, 'sex': 'male', 'bmi': 29.8, 'children': 3, 'smoker': 'yes', 'region': 'northeast', 'expenses': 30184.94}
# 93: {'_id': ObjectId('64e5a010ab40cfa92024889c'), 'age': 35, 'sex': 'male', 'bmi': 34.8, 'children': 2, 'smoker': 'no', 'region': 'northwest', 'expenses': 5729.01}
# 94: {'_id': ObjectId('64e5a010ab40cfa92024889d'), 'age': 64, 'sex': 'female', 'bmi': 31.3, 'children': 2, 'smoker': 'yes', 'region': 'southwest', 'expenses': 47291.06}
# 95: {'_id': ObjectId('64e5a010ab40cfa92024889e'), 'age': 28, 'sex': 'female', 'bmi': 37.6, 'children': 1, 'smoker': 'no', 'region': 'southeast', 'expenses': 3766.88}
# 96: {'_id': ObjectId('64e5a010ab40cfa92024889f'), 'age': 54, 'sex': 'female', 'bmi': 30.8, 'children': 3, 'smoker': 'no', 'region': 'southwest', 'expenses': 12105.32}
# 97: {'_id': ObjectId('64e5a010ab40cfa9202488a0'), 'age': 55, 'sex': 'male', 'bmi': 38.3, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 10226.28}
# 98: {'_id': ObjectId('64e5a010ab40cfa9202488a1'), 'age': 56, 'sex': 'male', 'bmi': 20.0, 'children': 0, 'smoker': 'yes', 'region': 'northeast', 'expenses': 22412.65}
# 99: {'_id': ObjectId('64e5a010ab40cfa9202488a2'), 'age': 38, 'sex': 'male', 'bmi': 19.3, 'children': 0, 'smoker': 'yes', 'region': 'southwest', 'expenses': 15820.7}
# 100: {'_id': ObjectId('64e5a010ab40cfa9202488a3'), 'age': 41, 'sex': 'female', 'bmi': 31.6, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 6186.13}
# 101: {'_id': ObjectId('64e5a010ab40cfa9202488a4'), 'age': 30, 'sex': 'male', 'bmi': 25.5, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 3645.09}
# 102: {'_id': ObjectId('64e5a010ab40cfa9202488a5'), 'age': 18, 'sex': 'female', 'bmi': 30.1, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 21344.85}
# 103: {'_id': ObjectId('64e5a010ab40cfa9202488a6'), 'age': 61, 'sex': 'female', 'bmi': 29.9, 'children': 3, 'smoker': 'yes', 'region': 'southeast', 'expenses': 30942.19}
# 104: {'_id': ObjectId('64e5a010ab40cfa9202488a7'), 'age': 34, 'sex': 'female', 'bmi': 27.5, 'children': 1, 'smoker': 'no', 'region': 'southwest', 'expenses': 5003.85}
# 105: {'_id': ObjectId('64e5a010ab40cfa9202488a8'), 'age': 20, 'sex': 'male', 'bmi': 28.0, 'children': 1, 'smoker': 'yes', 'region': 'northwest', 'expenses': 17560.38}
# 106: {'_id': ObjectId('64e5a010ab40cfa9202488a9'), 'age': 19, 'sex': 'female', 'bmi': 28.4, 'children': 1, 'smoker': 'no', 'region': 'southwest', 'expenses': 2331.52}
# 107: {'_id': ObjectId('64e5a010ab40cfa9202488aa'), 'age': 26, 'sex': 'male', 'bmi': 30.9, 'children': 2, 'smoker': 'no', 'region': 'northwest', 'expenses': 3877.3}
# 108: {'_id': ObjectId('64e5a010ab40cfa9202488ab'), 'age': 29, 'sex': 'male', 'bmi': 27.9, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 2867.12}
# 109: {'_id': ObjectId('64e5a010ab40cfa9202488ac'), 'age': 63, 'sex': 'male', 'bmi': 35.1, 'children': 0, 'smoker': 'yes', 'region': 'southeast', 'expenses': 47055.53}
# 110: {'_id': ObjectId('64e5a010ab40cfa9202488ad'), 'age': 54, 'sex': 'male', 'bmi': 33.6, 'children': 1, 'smoker': 'no', 'region': 'northwest', 'expenses': 10825.25}
# 111: {'_id': ObjectId('64e5a010ab40cfa9202488ae'), 'age': 55, 'sex': 'female', 'bmi': 29.7, 'children': 2, 'smoker': 'no', 'region': 'southwest', 'expenses': 11881.36}
# 112: {'_id': ObjectId('64e5a010ab40cfa9202488af'), 'age': 37, 'sex': 'male', 'bmi': 30.8, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 4646.76}
# 113: {'_id': ObjectId('64e5a010ab40cfa9202488b0'), 'age': 21, 'sex': 'female', 'bmi': 35.7, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 2404.73}
# 114: {'_id': ObjectId('64e5a010ab40cfa9202488b1'), 'age': 52, 'sex': 'male', 'bmi': 32.2, 'children': 3, 'smoker': 'no', 'region': 'northeast', 'expenses': 11488.32}
# 115: {'_id': ObjectId('64e5a010ab40cfa9202488b2'), 'age': 60, 'sex': 'male', 'bmi': 28.6, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 30260.0}
# 116: {'_id': ObjectId('64e5a010ab40cfa9202488b3'), 'age': 58, 'sex': 'male', 'bmi': 49.1, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 11381.33}
# 117: {'_id': ObjectId('64e5a010ab40cfa9202488b4'), 'age': 29, 'sex': 'female', 'bmi': 27.9, 'children': 1, 'smoker': 'yes', 'region': 'southeast', 'expenses': 19107.78}
# 118: {'_id': ObjectId('64e5a010ab40cfa9202488b5'), 'age': 49, 'sex': 'female', 'bmi': 27.2, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 8601.33}
# 119: {'_id': ObjectId('64e5a010ab40cfa9202488b6'), 'age': 37, 'sex': 'female', 'bmi': 23.4, 'children': 2, 'smoker': 'no', 'region': 'northwest', 'expenses': 6686.43}
# 120: {'_id': ObjectId('64e5a010ab40cfa9202488b7'), 'age': 44, 'sex': 'male', 'bmi': 37.1, 'children': 2, 'smoker': 'no', 'region': 'southwest', 'expenses': 7740.34}
# 121: {'_id': ObjectId('64e5a010ab40cfa9202488b8'), 'age': 18, 'sex': 'male', 'bmi': 23.8, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 1705.62}
# 122: {'_id': ObjectId('64e5a010ab40cfa9202488b9'), 'age': 20, 'sex': 'female', 'bmi': 29.0, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 2257.48}
# 123: {'_id': ObjectId('64e5a010ab40cfa9202488ba'), 'age': 44, 'sex': 'male', 'bmi': 31.4, 'children': 1, 'smoker': 'yes', 'region': 'northeast', 'expenses': 39556.49}
# 124: {'_id': ObjectId('64e5a010ab40cfa9202488bb'), 'age': 47, 'sex': 'female', 'bmi': 33.9, 'children': 3, 'smoker': 'no', 'region': 'northwest', 'expenses': 10115.01}
# 125: {'_id': ObjectId('64e5a010ab40cfa9202488bc'), 'age': 26, 'sex': 'female', 'bmi': 28.8, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 3385.4}
# 126: {'_id': ObjectId('64e5a010ab40cfa9202488bd'), 'age': 19, 'sex': 'female', 'bmi': 28.3, 'children': 0, 'smoker': 'yes', 'region': 'southwest', 'expenses': 17081.08}
# 127: {'_id': ObjectId('64e5a010ab40cfa9202488be'), 'age': 52, 'sex': 'female', 'bmi': 37.4, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 9634.54}
# 128: {'_id': ObjectId('64e5a010ab40cfa9202488bf'), 'age': 32, 'sex': 'female', 'bmi': 17.8, 'children': 2, 'smoker': 'yes', 'region': 'northwest', 'expenses': 32734.19}
# 129: {'_id': ObjectId('64e5a010ab40cfa9202488c0'), 'age': 38, 'sex': 'male', 'bmi': 34.7, 'children': 2, 'smoker': 'no', 'region': 'southwest', 'expenses': 6082.41}
# 130: {'_id': ObjectId('64e5a010ab40cfa9202488c1'), 'age': 59, 'sex': 'female', 'bmi': 26.5, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 12815.44}
# 131: {'_id': ObjectId('64e5a010ab40cfa9202488c2'), 'age': 61, 'sex': 'female', 'bmi': 22.0, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 13616.36}
# 132: {'_id': ObjectId('64e5a010ab40cfa9202488c3'), 'age': 53, 'sex': 'female', 'bmi': 35.9, 'children': 2, 'smoker': 'no', 'region': 'southwest', 'expenses': 11163.57}
# 133: {'_id': ObjectId('64e5a010ab40cfa9202488c4'), 'age': 19, 'sex': 'male', 'bmi': 25.6, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 1632.56}
# 134: {'_id': ObjectId('64e5a010ab40cfa9202488c5'), 'age': 20, 'sex': 'female', 'bmi': 28.8, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 2457.21}
# 135: {'_id': ObjectId('64e5a010ab40cfa9202488c6'), 'age': 22, 'sex': 'female', 'bmi': 28.1, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 2155.68}
# 136: {'_id': ObjectId('64e5a010ab40cfa9202488c7'), 'age': 19, 'sex': 'male', 'bmi': 34.1, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 1261.44}
# 137: {'_id': ObjectId('64e5a010ab40cfa9202488c8'), 'age': 22, 'sex': 'male', 'bmi': 25.2, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 2045.69}
# 138: {'_id': ObjectId('64e5a010ab40cfa9202488c9'), 'age': 54, 'sex': 'female', 'bmi': 31.9, 'children': 3, 'smoker': 'no', 'region': 'southeast', 'expenses': 27322.73}
# 139: {'_id': ObjectId('64e5a010ab40cfa9202488ca'), 'age': 22, 'sex': 'female', 'bmi': 36.0, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 2166.73}
# 140: {'_id': ObjectId('64e5a010ab40cfa9202488cb'), 'age': 34, 'sex': 'male', 'bmi': 22.4, 'children': 2, 'smoker': 'no', 'region': 'northeast', 'expenses': 27375.9}
# 141: {'_id': ObjectId('64e5a010ab40cfa9202488cc'), 'age': 26, 'sex': 'male', 'bmi': 32.5, 'children': 1, 'smoker': 'no', 'region': 'northeast', 'expenses': 3490.55}
# 142: {'_id': ObjectId('64e5a010ab40cfa9202488cd'), 'age': 34, 'sex': 'male', 'bmi': 25.3, 'children': 2, 'smoker': 'yes', 'region': 'southeast', 'expenses': 18972.5}
# 143: {'_id': ObjectId('64e5a010ab40cfa9202488ce'), 'age': 29, 'sex': 'male', 'bmi': 29.7, 'children': 2, 'smoker': 'no', 'region': 'northwest', 'expenses': 18157.88}
# 144: {'_id': ObjectId('64e5a010ab40cfa9202488cf'), 'age': 30, 'sex': 'male', 'bmi': 28.7, 'children': 3, 'smoker': 'yes', 'region': 'northwest', 'expenses': 20745.99}
# 145: {'_id': ObjectId('64e5a010ab40cfa9202488d0'), 'age': 29, 'sex': 'female', 'bmi': 38.8, 'children': 3, 'smoker': 'no', 'region': 'southeast', 'expenses': 5138.26}
# 146: {'_id': ObjectId('64e5a010ab40cfa9202488d1'), 'age': 46, 'sex': 'male', 'bmi': 30.5, 'children': 3, 'smoker': 'yes', 'region': 'northwest', 'expenses': 40720.55}
# 147: {'_id': ObjectId('64e5a010ab40cfa9202488d2'), 'age': 51, 'sex': 'female', 'bmi': 37.7, 'children': 1, 'smoker': 'no', 'region': 'southeast', 'expenses': 9877.61}
# 148: {'_id': ObjectId('64e5a010ab40cfa9202488d3'), 'age': 53, 'sex': 'female', 'bmi': 37.4, 'children': 1, 'smoker': 'no', 'region': 'northwest', 'expenses': 10959.69}
# 149: {'_id': ObjectId('64e5a010ab40cfa9202488d4'), 'age': 19, 'sex': 'male', 'bmi': 28.4, 'children': 1, 'smoker': 'no', 'region': 'southwest', 'expenses': 1842.52}
# 150: {'_id': ObjectId('64e5a010ab40cfa9202488d5'), 'age': 35, 'sex': 'male', 'bmi': 24.1, 'children': 1, 'smoker': 'no', 'region': 'northwest', 'expenses': 5125.22}
# 151: {'_id': ObjectId('64e5a010ab40cfa9202488d6'), 'age': 48, 'sex': 'male', 'bmi': 29.7, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 7789.64}
# 152: {'_id': ObjectId('64e5a010ab40cfa9202488d7'), 'age': 32, 'sex': 'female', 'bmi': 37.1, 'children': 3, 'smoker': 'no', 'region': 'northeast', 'expenses': 6334.34}
# 153: {'_id': ObjectId('64e5a010ab40cfa9202488d8'), 'age': 42, 'sex': 'female', 'bmi': 23.4, 'children': 0, 'smoker': 'yes', 'region': 'northeast', 'expenses': 19964.75}
# 154: {'_id': ObjectId('64e5a010ab40cfa9202488d9'), 'age': 40, 'sex': 'female', 'bmi': 25.5, 'children': 1, 'smoker': 'no', 'region': 'northeast', 'expenses': 7077.19}
# 155: {'_id': ObjectId('64e5a010ab40cfa9202488da'), 'age': 44, 'sex': 'male', 'bmi': 39.5, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 6948.7}
# 156: {'_id': ObjectId('64e5a010ab40cfa9202488db'), 'age': 48, 'sex': 'male', 'bmi': 24.4, 'children': 0, 'smoker': 'yes', 'region': 'southeast', 'expenses': 21223.68}
# 157: {'_id': ObjectId('64e5a010ab40cfa9202488dc'), 'age': 18, 'sex': 'male', 'bmi': 25.2, 'children': 0, 'smoker': 'yes', 'region': 'northeast', 'expenses': 15518.18}
# 158: {'_id': ObjectId('64e5a010ab40cfa9202488dd'), 'age': 30, 'sex': 'male', 'bmi': 35.5, 'children': 0, 'smoker': 'yes', 'region': 'southeast', 'expenses': 36950.26}
# 159: {'_id': ObjectId('64e5a010ab40cfa9202488de'), 'age': 50, 'sex': 'female', 'bmi': 27.8, 'children': 3, 'smoker': 'no', 'region': 'southeast', 'expenses': 19749.38}
# 160: {'_id': ObjectId('64e5a010ab40cfa9202488df'), 'age': 42, 'sex': 'female', 'bmi': 26.6, 'children': 0, 'smoker': 'yes', 'region': 'northwest', 'expenses': 21348.71}
# 161: {'_id': ObjectId('64e5a010ab40cfa9202488e0'), 'age': 18, 'sex': 'female', 'bmi': 36.9, 'children': 0, 'smoker': 'yes', 'region': 'southeast', 'expenses': 36149.48}
# 162: {'_id': ObjectId('64e5a010ab40cfa9202488e1'), 'age': 54, 'sex': 'male', 'bmi': 39.6, 'children': 1, 'smoker': 'no', 'region': 'southwest', 'expenses': 10450.55}
# 163: {'_id': ObjectId('64e5a010ab40cfa9202488e2'), 'age': 32, 'sex': 'female', 'bmi': 29.8, 'children': 2, 'smoker': 'no', 'region': 'southwest', 'expenses': 5152.13}
# 164: {'_id': ObjectId('64e5a010ab40cfa9202488e3'), 'age': 37, 'sex': 'male', 'bmi': 29.6, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 5028.15}
# 165: {'_id': ObjectId('64e5a010ab40cfa9202488e4'), 'age': 47, 'sex': 'male', 'bmi': 28.2, 'children': 4, 'smoker': 'no', 'region': 'northeast', 'expenses': 10407.09}
# 166: {'_id': ObjectId('64e5a010ab40cfa9202488e5'), 'age': 20, 'sex': 'female', 'bmi': 37.0, 'children': 5, 'smoker': 'no', 'region': 'southwest', 'expenses': 4830.63}
# 167: {'_id': ObjectId('64e5a010ab40cfa9202488e6'), 'age': 32, 'sex': 'female', 'bmi': 33.2, 'children': 3, 'smoker': 'no', 'region': 'northwest', 'expenses': 6128.8}
# 168: {'_id': ObjectId('64e5a010ab40cfa9202488e7'), 'age': 19, 'sex': 'female', 'bmi': 31.8, 'children': 1, 'smoker': 'no', 'region': 'northwest', 'expenses': 2719.28}
# 169: {'_id': ObjectId('64e5a010ab40cfa9202488e8'), 'age': 27, 'sex': 'male', 'bmi': 18.9, 'children': 3, 'smoker': 'no', 'region': 'northeast', 'expenses': 4827.9}
# 170: {'_id': ObjectId('64e5a010ab40cfa9202488e9'), 'age': 63, 'sex': 'male', 'bmi': 41.5, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 13405.39}
# 171: {'_id': ObjectId('64e5a010ab40cfa9202488ea'), 'age': 49, 'sex': 'male', 'bmi': 30.3, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 8116.68}
# 172: {'_id': ObjectId('64e5a010ab40cfa9202488eb'), 'age': 18, 'sex': 'male', 'bmi': 16.0, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 1694.8}
# 173: {'_id': ObjectId('64e5a010ab40cfa9202488ec'), 'age': 35, 'sex': 'female', 'bmi': 34.8, 'children': 1, 'smoker': 'no', 'region': 'southwest', 'expenses': 5246.05}
# 174: {'_id': ObjectId('64e5a010ab40cfa9202488ed'), 'age': 24, 'sex': 'female', 'bmi': 33.3, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 2855.44}
# 175: {'_id': ObjectId('64e5a010ab40cfa9202488ee'), 'age': 63, 'sex': 'female', 'bmi': 37.7, 'children': 0, 'smoker': 'yes', 'region': 'southwest', 'expenses': 48824.45}
# 176: {'_id': ObjectId('64e5a010ab40cfa9202488ef'), 'age': 38, 'sex': 'male', 'bmi': 27.8, 'children': 2, 'smoker': 'no', 'region': 'northwest', 'expenses': 6455.86}
# 177: {'_id': ObjectId('64e5a010ab40cfa9202488f0'), 'age': 54, 'sex': 'male', 'bmi': 29.2, 'children': 1, 'smoker': 'no', 'region': 'southwest', 'expenses': 10436.1}
# 178: {'_id': ObjectId('64e5a010ab40cfa9202488f1'), 'age': 46, 'sex': 'female', 'bmi': 28.9, 'children': 2, 'smoker': 'no', 'region': 'southwest', 'expenses': 8823.28}
# 179: {'_id': ObjectId('64e5a010ab40cfa9202488f2'), 'age': 41, 'sex': 'female', 'bmi': 33.2, 'children': 3, 'smoker': 'no', 'region': 'northeast', 'expenses': 8538.29}
# 180: {'_id': ObjectId('64e5a010ab40cfa9202488f3'), 'age': 58, 'sex': 'male', 'bmi': 28.6, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 11735.88}
# 181: {'_id': ObjectId('64e5a010ab40cfa9202488f4'), 'age': 18, 'sex': 'female', 'bmi': 38.3, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 1631.82}
# 182: {'_id': ObjectId('64e5a010ab40cfa9202488f5'), 'age': 22, 'sex': 'male', 'bmi': 20.0, 'children': 3, 'smoker': 'no', 'region': 'northeast', 'expenses': 4005.42}
# 183: {'_id': ObjectId('64e5a010ab40cfa9202488f6'), 'age': 44, 'sex': 'female', 'bmi': 26.4, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 7419.48}
# 184: {'_id': ObjectId('64e5a010ab40cfa9202488f7'), 'age': 44, 'sex': 'male', 'bmi': 30.7, 'children': 2, 'smoker': 'no', 'region': 'southeast', 'expenses': 7731.43}
# 185: {'_id': ObjectId('64e5a010ab40cfa9202488f8'), 'age': 36, 'sex': 'male', 'bmi': 41.9, 'children': 3, 'smoker': 'yes', 'region': 'northeast', 'expenses': 43753.34}
# 186: {'_id': ObjectId('64e5a010ab40cfa9202488f9'), 'age': 26, 'sex': 'female', 'bmi': 29.9, 'children': 2, 'smoker': 'no', 'region': 'southeast', 'expenses': 3981.98}
# 187: {'_id': ObjectId('64e5a010ab40cfa9202488fa'), 'age': 30, 'sex': 'female', 'bmi': 30.9, 'children': 3, 'smoker': 'no', 'region': 'southwest', 'expenses': 5325.65}
# 188: {'_id': ObjectId('64e5a010ab40cfa9202488fb'), 'age': 41, 'sex': 'female', 'bmi': 32.2, 'children': 1, 'smoker': 'no', 'region': 'southwest', 'expenses': 6775.96}
# 189: {'_id': ObjectId('64e5a010ab40cfa9202488fc'), 'age': 29, 'sex': 'female', 'bmi': 32.1, 'children': 2, 'smoker': 'no', 'region': 'northwest', 'expenses': 4922.92}
# 190: {'_id': ObjectId('64e5a010ab40cfa9202488fd'), 'age': 61, 'sex': 'male', 'bmi': 31.6, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 12557.61}
# 191: {'_id': ObjectId('64e5a010ab40cfa9202488fe'), 'age': 36, 'sex': 'female', 'bmi': 26.2, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 4883.87}
# 192: {'_id': ObjectId('64e5a010ab40cfa9202488ff'), 'age': 25, 'sex': 'male', 'bmi': 25.7, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 2137.65}
# 193: {'_id': ObjectId('64e5a010ab40cfa920248900'), 'age': 56, 'sex': 'female', 'bmi': 26.6, 'children': 1, 'smoker': 'no', 'region': 'northwest', 'expenses': 12044.34}
# 194: {'_id': ObjectId('64e5a010ab40cfa920248901'), 'age': 18, 'sex': 'male', 'bmi': 34.4, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 1137.47}
# 195: {'_id': ObjectId('64e5a010ab40cfa920248902'), 'age': 19, 'sex': 'male', 'bmi': 30.6, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 1639.56}
# 196: {'_id': ObjectId('64e5a010ab40cfa920248903'), 'age': 39, 'sex': 'female', 'bmi': 32.8, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 5649.72}
# 197: {'_id': ObjectId('64e5a010ab40cfa920248904'), 'age': 45, 'sex': 'female', 'bmi': 28.6, 'children': 2, 'smoker': 'no', 'region': 'southeast', 'expenses': 8516.83}
# 198: {'_id': ObjectId('64e5a010ab40cfa920248905'), 'age': 51, 'sex': 'female', 'bmi': 18.1, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 9644.25}
# 199: {'_id': ObjectId('64e5a010ab40cfa920248906'), 'age': 64, 'sex': 'female', 'bmi': 39.3, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 14901.52}
# 200: {'_id': ObjectId('64e5a010ab40cfa920248907'), 'age': 19, 'sex': 'female', 'bmi': 32.1, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 2130.68}
# 201: {'_id': ObjectId('64e5a010ab40cfa920248908'), 'age': 48, 'sex': 'female', 'bmi': 32.2, 'children': 1, 'smoker': 'no', 'region': 'southeast', 'expenses': 8871.15}
# 202: {'_id': ObjectId('64e5a010ab40cfa920248909'), 'age': 60, 'sex': 'female', 'bmi': 24.0, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 13012.21}
# 203: {'_id': ObjectId('64e5a010ab40cfa92024890a'), 'age': 27, 'sex': 'female', 'bmi': 36.1, 'children': 0, 'smoker': 'yes', 'region': 'southeast', 'expenses': 37133.9}
# 204: {'_id': ObjectId('64e5a010ab40cfa92024890b'), 'age': 46, 'sex': 'male', 'bmi': 22.3, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 7147.11}
# 205: {'_id': ObjectId('64e5a010ab40cfa92024890c'), 'age': 28, 'sex': 'female', 'bmi': 28.9, 'children': 1, 'smoker': 'no', 'region': 'northeast', 'expenses': 4337.74}
# 206: {'_id': ObjectId('64e5a010ab40cfa92024890d'), 'age': 59, 'sex': 'male', 'bmi': 26.4, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 11743.3}
# 207: {'_id': ObjectId('64e5a010ab40cfa92024890e'), 'age': 35, 'sex': 'male', 'bmi': 27.7, 'children': 2, 'smoker': 'yes', 'region': 'northeast', 'expenses': 20984.09}
# 208: {'_id': ObjectId('64e5a010ab40cfa92024890f'), 'age': 63, 'sex': 'female', 'bmi': 31.8, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 13880.95}
# 209: {'_id': ObjectId('64e5a010ab40cfa920248910'), 'age': 40, 'sex': 'male', 'bmi': 41.2, 'children': 1, 'smoker': 'no', 'region': 'northeast', 'expenses': 6610.11}
# 210: {'_id': ObjectId('64e5a010ab40cfa920248911'), 'age': 20, 'sex': 'male', 'bmi': 33.0, 'children': 1, 'smoker': 'no', 'region': 'southwest', 'expenses': 1980.07}
# 211: {'_id': ObjectId('64e5a010ab40cfa920248912'), 'age': 40, 'sex': 'male', 'bmi': 30.9, 'children': 4, 'smoker': 'no', 'region': 'northwest', 'expenses': 8162.72}
# 212: {'_id': ObjectId('64e5a010ab40cfa920248913'), 'age': 24, 'sex': 'male', 'bmi': 28.5, 'children': 2, 'smoker': 'no', 'region': 'northwest', 'expenses': 3537.7}
# 213: {'_id': ObjectId('64e5a010ab40cfa920248914'), 'age': 34, 'sex': 'female', 'bmi': 26.7, 'children': 1, 'smoker': 'no', 'region': 'southeast', 'expenses': 5002.78}
# 214: {'_id': ObjectId('64e5a010ab40cfa920248915'), 'age': 45, 'sex': 'female', 'bmi': 30.9, 'children': 2, 'smoker': 'no', 'region': 'southwest', 'expenses': 8520.03}
# 215: {'_id': ObjectId('64e5a010ab40cfa920248916'), 'age': 41, 'sex': 'female', 'bmi': 37.1, 'children': 2, 'smoker': 'no', 'region': 'southwest', 'expenses': 7371.77}
# 216: {'_id': ObjectId('64e5a010ab40cfa920248917'), 'age': 53, 'sex': 'female', 'bmi': 26.6, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 10355.64}
# 217: {'_id': ObjectId('64e5a010ab40cfa920248918'), 'age': 27, 'sex': 'male', 'bmi': 23.1, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 2483.74}
# 218: {'_id': ObjectId('64e5a010ab40cfa920248919'), 'age': 26, 'sex': 'female', 'bmi': 29.9, 'children': 1, 'smoker': 'no', 'region': 'southeast', 'expenses': 3392.98}
# 219: {'_id': ObjectId('64e5a010ab40cfa92024891a'), 'age': 24, 'sex': 'female', 'bmi': 23.2, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 25081.77}
# 220: {'_id': ObjectId('64e5a010ab40cfa92024891b'), 'age': 34, 'sex': 'female', 'bmi': 33.7, 'children': 1, 'smoker': 'no', 'region': 'southwest', 'expenses': 5012.47}
# 221: {'_id': ObjectId('64e5a010ab40cfa92024891c'), 'age': 53, 'sex': 'female', 'bmi': 33.3, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 10564.88}
# 222: {'_id': ObjectId('64e5a010ab40cfa92024891d'), 'age': 32, 'sex': 'male', 'bmi': 30.8, 'children': 3, 'smoker': 'no', 'region': 'southwest', 'expenses': 5253.52}
# 223: {'_id': ObjectId('64e5a010ab40cfa92024891e'), 'age': 19, 'sex': 'male', 'bmi': 34.8, 'children': 0, 'smoker': 'yes', 'region': 'southwest', 'expenses': 34779.62}
# 224: {'_id': ObjectId('64e5a010ab40cfa92024891f'), 'age': 42, 'sex': 'male', 'bmi': 24.6, 'children': 0, 'smoker': 'yes', 'region': 'southeast', 'expenses': 19515.54}
# 225: {'_id': ObjectId('64e5a010ab40cfa920248920'), 'age': 55, 'sex': 'male', 'bmi': 33.9, 'children': 3, 'smoker': 'no', 'region': 'southeast', 'expenses': 11987.17}
# 226: {'_id': ObjectId('64e5a010ab40cfa920248921'), 'age': 28, 'sex': 'male', 'bmi': 38.1, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 2689.5}
# 227: {'_id': ObjectId('64e5a010ab40cfa920248922'), 'age': 58, 'sex': 'female', 'bmi': 41.9, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 24227.34}
# 228: {'_id': ObjectId('64e5a010ab40cfa920248923'), 'age': 41, 'sex': 'female', 'bmi': 31.6, 'children': 1, 'smoker': 'no', 'region': 'northeast', 'expenses': 7358.18}
# 229: {'_id': ObjectId('64e5a010ab40cfa920248924'), 'age': 47, 'sex': 'male', 'bmi': 25.5, 'children': 2, 'smoker': 'no', 'region': 'northeast', 'expenses': 9225.26}
# 230: {'_id': ObjectId('64e5a010ab40cfa920248925'), 'age': 42, 'sex': 'female', 'bmi': 36.2, 'children': 1, 'smoker': 'no', 'region': 'northwest', 'expenses': 7443.64}
# 231: {'_id': ObjectId('64e5a010ab40cfa920248926'), 'age': 59, 'sex': 'female', 'bmi': 27.8, 'children': 3, 'smoker': 'no', 'region': 'southeast', 'expenses': 14001.29}
# 232: {'_id': ObjectId('64e5a010ab40cfa920248927'), 'age': 19, 'sex': 'female', 'bmi': 17.8, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 1727.79}
# 233: {'_id': ObjectId('64e5a010ab40cfa920248928'), 'age': 59, 'sex': 'male', 'bmi': 27.5, 'children': 1, 'smoker': 'no', 'region': 'southwest', 'expenses': 12333.83}
# 234: {'_id': ObjectId('64e5a010ab40cfa920248929'), 'age': 39, 'sex': 'male', 'bmi': 24.5, 'children': 2, 'smoker': 'no', 'region': 'northwest', 'expenses': 6710.19}
# 235: {'_id': ObjectId('64e5a010ab40cfa92024892a'), 'age': 40, 'sex': 'female', 'bmi': 22.2, 'children': 2, 'smoker': 'yes', 'region': 'southeast', 'expenses': 19444.27}
# 236: {'_id': ObjectId('64e5a010ab40cfa92024892b'), 'age': 18, 'sex': 'female', 'bmi': 26.7, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 1615.77}
# 237: {'_id': ObjectId('64e5a010ab40cfa92024892c'), 'age': 31, 'sex': 'male', 'bmi': 38.4, 'children': 2, 'smoker': 'no', 'region': 'southeast', 'expenses': 4463.21}
# 238: {'_id': ObjectId('64e5a010ab40cfa92024892d'), 'age': 19, 'sex': 'male', 'bmi': 29.1, 'children': 0, 'smoker': 'yes', 'region': 'northwest', 'expenses': 17352.68}
# 239: {'_id': ObjectId('64e5a010ab40cfa92024892e'), 'age': 44, 'sex': 'male', 'bmi': 38.1, 'children': 1, 'smoker': 'no', 'region': 'southeast', 'expenses': 7152.67}
# 240: {'_id': ObjectId('64e5a010ab40cfa92024892f'), 'age': 23, 'sex': 'female', 'bmi': 36.7, 'children': 2, 'smoker': 'yes', 'region': 'northeast', 'expenses': 38511.63}
# 241: {'_id': ObjectId('64e5a010ab40cfa920248930'), 'age': 33, 'sex': 'female', 'bmi': 22.1, 'children': 1, 'smoker': 'no', 'region': 'northeast', 'expenses': 5354.07}
# 242: {'_id': ObjectId('64e5a010ab40cfa920248931'), 'age': 55, 'sex': 'female', 'bmi': 26.8, 'children': 1, 'smoker': 'no', 'region': 'southwest', 'expenses': 35160.13}
# 243: {'_id': ObjectId('64e5a010ab40cfa920248932'), 'age': 40, 'sex': 'male', 'bmi': 35.3, 'children': 3, 'smoker': 'no', 'region': 'southwest', 'expenses': 7196.87}
# 244: {'_id': ObjectId('64e5a010ab40cfa920248933'), 'age': 63, 'sex': 'female', 'bmi': 27.7, 'children': 0, 'smoker': 'yes', 'region': 'northeast', 'expenses': 29523.17}
# 245: {'_id': ObjectId('64e5a010ab40cfa920248934'), 'age': 54, 'sex': 'male', 'bmi': 30.0, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 24476.48}
# 246: {'_id': ObjectId('64e5a010ab40cfa920248935'), 'age': 60, 'sex': 'female', 'bmi': 38.1, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 12648.7}
# 247: {'_id': ObjectId('64e5a010ab40cfa920248936'), 'age': 24, 'sex': 'male', 'bmi': 35.9, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 1986.93}
# 248: {'_id': ObjectId('64e5a010ab40cfa920248937'), 'age': 19, 'sex': 'male', 'bmi': 20.9, 'children': 1, 'smoker': 'no', 'region': 'southwest', 'expenses': 1832.09}
# 249: {'_id': ObjectId('64e5a010ab40cfa920248938'), 'age': 29, 'sex': 'male', 'bmi': 29.0, 'children': 1, 'smoker': 'no', 'region': 'northeast', 'expenses': 4040.56}
# 250: {'_id': ObjectId('64e5a010ab40cfa920248939'), 'age': 18, 'sex': 'male', 'bmi': 17.3, 'children': 2, 'smoker': 'yes', 'region': 'northeast', 'expenses': 12829.46}
# 251: {'_id': ObjectId('64e5a010ab40cfa92024893a'), 'age': 63, 'sex': 'female', 'bmi': 32.2, 'children': 2, 'smoker': 'yes', 'region': 'southwest', 'expenses': 47305.31}
# 252: {'_id': ObjectId('64e5a010ab40cfa92024893b'), 'age': 54, 'sex': 'male', 'bmi': 34.2, 'children': 2, 'smoker': 'yes', 'region': 'southeast', 'expenses': 44260.75}
# 253: {'_id': ObjectId('64e5a010ab40cfa92024893c'), 'age': 27, 'sex': 'male', 'bmi': 30.3, 'children': 3, 'smoker': 'no', 'region': 'southwest', 'expenses': 4260.74}
# 254: {'_id': ObjectId('64e5a010ab40cfa92024893d'), 'age': 50, 'sex': 'male', 'bmi': 31.8, 'children': 0, 'smoker': 'yes', 'region': 'northeast', 'expenses': 41097.16}
# 255: {'_id': ObjectId('64e5a010ab40cfa92024893e'), 'age': 55, 'sex': 'female', 'bmi': 25.4, 'children': 3, 'smoker': 'no', 'region': 'northeast', 'expenses': 13047.33}
# 256: {'_id': ObjectId('64e5a010ab40cfa92024893f'), 'age': 56, 'sex': 'male', 'bmi': 33.6, 'children': 0, 'smoker': 'yes', 'region': 'northwest', 'expenses': 43921.18}
# 257: {'_id': ObjectId('64e5a010ab40cfa920248940'), 'age': 38, 'sex': 'female', 'bmi': 40.2, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 5400.98}
# 258: {'_id': ObjectId('64e5a010ab40cfa920248941'), 'age': 51, 'sex': 'male', 'bmi': 24.4, 'children': 4, 'smoker': 'no', 'region': 'northwest', 'expenses': 11520.1}
# 259: {'_id': ObjectId('64e5a010ab40cfa920248942'), 'age': 19, 'sex': 'male', 'bmi': 31.9, 'children': 0, 'smoker': 'yes', 'region': 'northwest', 'expenses': 33750.29}
# 260: {'_id': ObjectId('64e5a010ab40cfa920248943'), 'age': 58, 'sex': 'female', 'bmi': 25.2, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 11837.16}
# 261: {'_id': ObjectId('64e5a010ab40cfa920248944'), 'age': 20, 'sex': 'female', 'bmi': 26.8, 'children': 1, 'smoker': 'yes', 'region': 'southeast', 'expenses': 17085.27}
# 262: {'_id': ObjectId('64e5a010ab40cfa920248945'), 'age': 52, 'sex': 'male', 'bmi': 24.3, 'children': 3, 'smoker': 'yes', 'region': 'northeast', 'expenses': 24869.84}
# 263: {'_id': ObjectId('64e5a010ab40cfa920248946'), 'age': 19, 'sex': 'male', 'bmi': 37.0, 'children': 0, 'smoker': 'yes', 'region': 'northwest', 'expenses': 36219.41}
# 264: {'_id': ObjectId('64e5a010ab40cfa920248947'), 'age': 53, 'sex': 'female', 'bmi': 38.1, 'children': 3, 'smoker': 'no', 'region': 'southeast', 'expenses': 20463.0}
# 265: {'_id': ObjectId('64e5a010ab40cfa920248948'), 'age': 46, 'sex': 'male', 'bmi': 42.4, 'children': 3, 'smoker': 'yes', 'region': 'southeast', 'expenses': 46151.12}
# 266: {'_id': ObjectId('64e5a010ab40cfa920248949'), 'age': 40, 'sex': 'male', 'bmi': 19.8, 'children': 1, 'smoker': 'yes', 'region': 'southeast', 'expenses': 17179.52}
# 267: {'_id': ObjectId('64e5a010ab40cfa92024894a'), 'age': 59, 'sex': 'female', 'bmi': 32.4, 'children': 3, 'smoker': 'no', 'region': 'northeast', 'expenses': 14590.63}
# 268: {'_id': ObjectId('64e5a010ab40cfa92024894b'), 'age': 45, 'sex': 'male', 'bmi': 30.2, 'children': 1, 'smoker': 'no', 'region': 'southwest', 'expenses': 7441.05}
# 269: {'_id': ObjectId('64e5a010ab40cfa92024894c'), 'age': 49, 'sex': 'male', 'bmi': 25.8, 'children': 1, 'smoker': 'no', 'region': 'northeast', 'expenses': 9282.48}
# 270: {'_id': ObjectId('64e5a010ab40cfa92024894d'), 'age': 18, 'sex': 'male', 'bmi': 29.4, 'children': 1, 'smoker': 'no', 'region': 'southeast', 'expenses': 1719.44}
# 271: {'_id': ObjectId('64e5a010ab40cfa92024894e'), 'age': 50, 'sex': 'male', 'bmi': 34.2, 'children': 2, 'smoker': 'yes', 'region': 'southwest', 'expenses': 42856.84}
# 272: {'_id': ObjectId('64e5a010ab40cfa92024894f'), 'age': 41, 'sex': 'male', 'bmi': 37.1, 'children': 2, 'smoker': 'no', 'region': 'northwest', 'expenses': 7265.7}
# 273: {'_id': ObjectId('64e5a010ab40cfa920248950'), 'age': 50, 'sex': 'male', 'bmi': 27.5, 'children': 1, 'smoker': 'no', 'region': 'northeast', 'expenses': 9617.66}
# 274: {'_id': ObjectId('64e5a010ab40cfa920248951'), 'age': 25, 'sex': 'male', 'bmi': 27.6, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 2523.17}
# 275: {'_id': ObjectId('64e5a010ab40cfa920248952'), 'age': 47, 'sex': 'female', 'bmi': 26.6, 'children': 2, 'smoker': 'no', 'region': 'northeast', 'expenses': 9715.84}
# 276: {'_id': ObjectId('64e5a010ab40cfa920248953'), 'age': 19, 'sex': 'male', 'bmi': 20.6, 'children': 2, 'smoker': 'no', 'region': 'northwest', 'expenses': 2803.7}
# 277: {'_id': ObjectId('64e5a010ab40cfa920248954'), 'age': 22, 'sex': 'female', 'bmi': 24.3, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 2150.47}
# 278: {'_id': ObjectId('64e5a010ab40cfa920248955'), 'age': 59, 'sex': 'male', 'bmi': 31.8, 'children': 2, 'smoker': 'no', 'region': 'southeast', 'expenses': 12928.79}
# 279: {'_id': ObjectId('64e5a010ab40cfa920248956'), 'age': 51, 'sex': 'female', 'bmi': 21.6, 'children': 1, 'smoker': 'no', 'region': 'southeast', 'expenses': 9855.13}
# 280: {'_id': ObjectId('64e5a010ab40cfa920248957'), 'age': 40, 'sex': 'female', 'bmi': 28.1, 'children': 1, 'smoker': 'yes', 'region': 'northeast', 'expenses': 22331.57}
# 281: {'_id': ObjectId('64e5a010ab40cfa920248958'), 'age': 54, 'sex': 'male', 'bmi': 40.6, 'children': 3, 'smoker': 'yes', 'region': 'northeast', 'expenses': 48549.18}
# 282: {'_id': ObjectId('64e5a010ab40cfa920248959'), 'age': 30, 'sex': 'male', 'bmi': 27.6, 'children': 1, 'smoker': 'no', 'region': 'northeast', 'expenses': 4237.13}
# 283: {'_id': ObjectId('64e5a010ab40cfa92024895a'), 'age': 55, 'sex': 'female', 'bmi': 32.4, 'children': 1, 'smoker': 'no', 'region': 'northeast', 'expenses': 11879.1}
# 284: {'_id': ObjectId('64e5a010ab40cfa92024895b'), 'age': 52, 'sex': 'female', 'bmi': 31.2, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 9625.92}
# 285: {'_id': ObjectId('64e5a010ab40cfa92024895c'), 'age': 46, 'sex': 'male', 'bmi': 26.6, 'children': 1, 'smoker': 'no', 'region': 'southeast', 'expenses': 7742.11}
# 286: {'_id': ObjectId('64e5a010ab40cfa92024895d'), 'age': 46, 'sex': 'female', 'bmi': 48.1, 'children': 2, 'smoker': 'no', 'region': 'northeast', 'expenses': 9432.93}
# 287: {'_id': ObjectId('64e5a010ab40cfa92024895e'), 'age': 63, 'sex': 'female', 'bmi': 26.2, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 14256.19}
# ...
# 1243: {'_id': ObjectId('64e5a010ab40cfa920248d1a'), 'age': 28, 'sex': 'female', 'bmi': 33.1, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 3171.61}
# 1244: {'_id': ObjectId('64e5a010ab40cfa920248d1b'), 'age': 18, 'sex': 'male', 'bmi': 33.3, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 1135.94}
# 1245: {'_id': ObjectId('64e5a010ab40cfa920248d1c'), 'age': 28, 'sex': 'male', 'bmi': 24.3, 'children': 5, 'smoker': 'no', 'region': 'southwest', 'expenses': 5615.37}
# 1246: {'_id': ObjectId('64e5a010ab40cfa920248d1d'), 'age': 45, 'sex': 'female', 'bmi': 25.7, 'children': 3, 'smoker': 'no', 'region': 'southwest', 'expenses': 9101.8}
# 1247: {'_id': ObjectId('64e5a010ab40cfa920248d1e'), 'age': 33, 'sex': 'male', 'bmi': 29.4, 'children': 4, 'smoker': 'no', 'region': 'southwest', 'expenses': 6059.17}
# 1248: {'_id': ObjectId('64e5a010ab40cfa920248d1f'), 'age': 18, 'sex': 'female', 'bmi': 39.8, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 1633.96}
# 1249: {'_id': ObjectId('64e5a010ab40cfa920248d20'), 'age': 32, 'sex': 'male', 'bmi': 33.6, 'children': 1, 'smoker': 'yes', 'region': 'northeast', 'expenses': 37607.53}
# 1250: {'_id': ObjectId('64e5a010ab40cfa920248d21'), 'age': 24, 'sex': 'male', 'bmi': 29.8, 'children': 0, 'smoker': 'yes', 'region': 'northeast', 'expenses': 18648.42}
# 1251: {'_id': ObjectId('64e5a010ab40cfa920248d22'), 'age': 19, 'sex': 'male', 'bmi': 19.8, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 1241.57}
# 1252: {'_id': ObjectId('64e5a010ab40cfa920248d23'), 'age': 20, 'sex': 'male', 'bmi': 27.3, 'children': 0, 'smoker': 'yes', 'region': 'southwest', 'expenses': 16232.85}
# 1253: {'_id': ObjectId('64e5a010ab40cfa920248d24'), 'age': 40, 'sex': 'female', 'bmi': 29.3, 'children': 4, 'smoker': 'no', 'region': 'southwest', 'expenses': 15828.82}
# 1254: {'_id': ObjectId('64e5a010ab40cfa920248d25'), 'age': 34, 'sex': 'female', 'bmi': 27.7, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 4415.16}
# 1255: {'_id': ObjectId('64e5a010ab40cfa920248d26'), 'age': 42, 'sex': 'female', 'bmi': 37.9, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 6474.01}
# 1256: {'_id': ObjectId('64e5a010ab40cfa920248d27'), 'age': 51, 'sex': 'female', 'bmi': 36.4, 'children': 3, 'smoker': 'no', 'region': 'northwest', 'expenses': 11436.74}
# 1257: {'_id': ObjectId('64e5a010ab40cfa920248d28'), 'age': 54, 'sex': 'female', 'bmi': 27.6, 'children': 1, 'smoker': 'no', 'region': 'northwest', 'expenses': 11305.93}
# 1258: {'_id': ObjectId('64e5a010ab40cfa920248d29'), 'age': 55, 'sex': 'male', 'bmi': 37.7, 'children': 3, 'smoker': 'no', 'region': 'northwest', 'expenses': 30063.58}
# 1259: {'_id': ObjectId('64e5a010ab40cfa920248d2a'), 'age': 52, 'sex': 'female', 'bmi': 23.2, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 10197.77}
# 1260: {'_id': ObjectId('64e5a010ab40cfa920248d2b'), 'age': 32, 'sex': 'female', 'bmi': 20.5, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 4544.23}
# 1261: {'_id': ObjectId('64e5a010ab40cfa920248d2c'), 'age': 28, 'sex': 'male', 'bmi': 37.1, 'children': 1, 'smoker': 'no', 'region': 'southwest', 'expenses': 3277.16}
# 1262: {'_id': ObjectId('64e5a010ab40cfa920248d2d'), 'age': 41, 'sex': 'female', 'bmi': 28.1, 'children': 1, 'smoker': 'no', 'region': 'southeast', 'expenses': 6770.19}
# 1263: {'_id': ObjectId('64e5a010ab40cfa920248d2e'), 'age': 43, 'sex': 'female', 'bmi': 29.9, 'children': 1, 'smoker': 'no', 'region': 'southwest', 'expenses': 7337.75}
# 1264: {'_id': ObjectId('64e5a010ab40cfa920248d2f'), 'age': 49, 'sex': 'female', 'bmi': 33.3, 'children': 2, 'smoker': 'no', 'region': 'northeast', 'expenses': 10370.91}
# 1265: {'_id': ObjectId('64e5a010ab40cfa920248d30'), 'age': 64, 'sex': 'male', 'bmi': 23.8, 'children': 0, 'smoker': 'yes', 'region': 'southeast', 'expenses': 26926.51}
# 1266: {'_id': ObjectId('64e5a010ab40cfa920248d31'), 'age': 55, 'sex': 'female', 'bmi': 30.5, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 10704.47}
# 1267: {'_id': ObjectId('64e5a010ab40cfa920248d32'), 'age': 24, 'sex': 'male', 'bmi': 31.1, 'children': 0, 'smoker': 'yes', 'region': 'northeast', 'expenses': 34254.05}
# 1268: {'_id': ObjectId('64e5a010ab40cfa920248d33'), 'age': 20, 'sex': 'female', 'bmi': 33.3, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 1880.49}
# 1269: {'_id': ObjectId('64e5a010ab40cfa920248d34'), 'age': 45, 'sex': 'male', 'bmi': 27.5, 'children': 3, 'smoker': 'no', 'region': 'southwest', 'expenses': 8615.3}
# 1270: {'_id': ObjectId('64e5a010ab40cfa920248d35'), 'age': 26, 'sex': 'male', 'bmi': 33.9, 'children': 1, 'smoker': 'no', 'region': 'northwest', 'expenses': 3292.53}
# 1271: {'_id': ObjectId('64e5a010ab40cfa920248d36'), 'age': 25, 'sex': 'female', 'bmi': 34.5, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 3021.81}
# 1272: {'_id': ObjectId('64e5a010ab40cfa920248d37'), 'age': 43, 'sex': 'male', 'bmi': 25.5, 'children': 5, 'smoker': 'no', 'region': 'southeast', 'expenses': 14478.33}
# 1273: {'_id': ObjectId('64e5a010ab40cfa920248d38'), 'age': 35, 'sex': 'male', 'bmi': 27.6, 'children': 1, 'smoker': 'no', 'region': 'southeast', 'expenses': 4747.05}
# 1274: {'_id': ObjectId('64e5a010ab40cfa920248d39'), 'age': 26, 'sex': 'male', 'bmi': 27.1, 'children': 0, 'smoker': 'yes', 'region': 'southeast', 'expenses': 17043.34}
# 1275: {'_id': ObjectId('64e5a010ab40cfa920248d3a'), 'age': 57, 'sex': 'male', 'bmi': 23.7, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 10959.33}
# 1276: {'_id': ObjectId('64e5a010ab40cfa920248d3b'), 'age': 22, 'sex': 'female', 'bmi': 30.4, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 2741.95}
# 1277: {'_id': ObjectId('64e5a010ab40cfa920248d3c'), 'age': 32, 'sex': 'female', 'bmi': 29.7, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 4357.04}
# 1278: {'_id': ObjectId('64e5a010ab40cfa920248d3d'), 'age': 39, 'sex': 'male', 'bmi': 29.9, 'children': 1, 'smoker': 'yes', 'region': 'northeast', 'expenses': 22462.04}
# 1279: {'_id': ObjectId('64e5a010ab40cfa920248d3e'), 'age': 25, 'sex': 'female', 'bmi': 26.8, 'children': 2, 'smoker': 'no', 'region': 'northwest', 'expenses': 4189.11}
# 1280: {'_id': ObjectId('64e5a010ab40cfa920248d3f'), 'age': 48, 'sex': 'female', 'bmi': 33.3, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 8283.68}
# 1281: {'_id': ObjectId('64e5a010ab40cfa920248d40'), 'age': 47, 'sex': 'female', 'bmi': 27.6, 'children': 2, 'smoker': 'yes', 'region': 'northwest', 'expenses': 24535.7}
# 1282: {'_id': ObjectId('64e5a010ab40cfa920248d41'), 'age': 18, 'sex': 'female', 'bmi': 21.7, 'children': 0, 'smoker': 'yes', 'region': 'northeast', 'expenses': 14283.46}
# 1283: {'_id': ObjectId('64e5a010ab40cfa920248d42'), 'age': 18, 'sex': 'male', 'bmi': 30.0, 'children': 1, 'smoker': 'no', 'region': 'southeast', 'expenses': 1720.35}
# 1284: {'_id': ObjectId('64e5a010ab40cfa920248d43'), 'age': 61, 'sex': 'male', 'bmi': 36.3, 'children': 1, 'smoker': 'yes', 'region': 'southwest', 'expenses': 47403.88}
# 1285: {'_id': ObjectId('64e5a010ab40cfa920248d44'), 'age': 47, 'sex': 'female', 'bmi': 24.3, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 8534.67}
# 1286: {'_id': ObjectId('64e5a010ab40cfa920248d45'), 'age': 28, 'sex': 'female', 'bmi': 17.3, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 3732.63}
# 1287: {'_id': ObjectId('64e5a010ab40cfa920248d46'), 'age': 36, 'sex': 'female', 'bmi': 25.9, 'children': 1, 'smoker': 'no', 'region': 'southwest', 'expenses': 5472.45}
# 1288: {'_id': ObjectId('64e5a010ab40cfa920248d47'), 'age': 20, 'sex': 'male', 'bmi': 39.4, 'children': 2, 'smoker': 'yes', 'region': 'southwest', 'expenses': 38344.57}
# 1289: {'_id': ObjectId('64e5a010ab40cfa920248d48'), 'age': 44, 'sex': 'male', 'bmi': 34.3, 'children': 1, 'smoker': 'no', 'region': 'southeast', 'expenses': 7147.47}
# 1290: {'_id': ObjectId('64e5a010ab40cfa920248d49'), 'age': 38, 'sex': 'female', 'bmi': 20.0, 'children': 2, 'smoker': 'no', 'region': 'northeast', 'expenses': 7133.9}
# 1291: {'_id': ObjectId('64e5a010ab40cfa920248d4a'), 'age': 19, 'sex': 'male', 'bmi': 34.9, 'children': 0, 'smoker': 'yes', 'region': 'southwest', 'expenses': 34828.65}
# 1292: {'_id': ObjectId('64e5a010ab40cfa920248d4b'), 'age': 21, 'sex': 'male', 'bmi': 23.2, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 1515.34}
# 1293: {'_id': ObjectId('64e5a010ab40cfa920248d4c'), 'age': 46, 'sex': 'male', 'bmi': 25.7, 'children': 3, 'smoker': 'no', 'region': 'northwest', 'expenses': 9301.89}
# 1294: {'_id': ObjectId('64e5a010ab40cfa920248d4d'), 'age': 58, 'sex': 'male', 'bmi': 25.2, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 11931.13}
# 1295: {'_id': ObjectId('64e5a010ab40cfa920248d4e'), 'age': 20, 'sex': 'male', 'bmi': 22.0, 'children': 1, 'smoker': 'no', 'region': 'southwest', 'expenses': 1964.78}
# 1296: {'_id': ObjectId('64e5a010ab40cfa920248d4f'), 'age': 18, 'sex': 'male', 'bmi': 26.1, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 1708.93}
# 1297: {'_id': ObjectId('64e5a010ab40cfa920248d50'), 'age': 28, 'sex': 'female', 'bmi': 26.5, 'children': 2, 'smoker': 'no', 'region': 'southeast', 'expenses': 4340.44}
# 1298: {'_id': ObjectId('64e5a010ab40cfa920248d51'), 'age': 33, 'sex': 'male', 'bmi': 27.5, 'children': 2, 'smoker': 'no', 'region': 'northwest', 'expenses': 5261.47}
# 1299: {'_id': ObjectId('64e5a010ab40cfa920248d52'), 'age': 19, 'sex': 'female', 'bmi': 25.7, 'children': 1, 'smoker': 'no', 'region': 'northwest', 'expenses': 2710.83}
# 1300: {'_id': ObjectId('64e5a010ab40cfa920248d53'), 'age': 45, 'sex': 'male', 'bmi': 30.4, 'children': 0, 'smoker': 'yes', 'region': 'southeast', 'expenses': 62592.87}
# 1301: {'_id': ObjectId('64e5a010ab40cfa920248d54'), 'age': 62, 'sex': 'male', 'bmi': 30.9, 'children': 3, 'smoker': 'yes', 'region': 'northwest', 'expenses': 46718.16}
# 1302: {'_id': ObjectId('64e5a010ab40cfa920248d55'), 'age': 25, 'sex': 'female', 'bmi': 20.8, 'children': 1, 'smoker': 'no', 'region': 'southwest', 'expenses': 3208.79}
# 1303: {'_id': ObjectId('64e5a010ab40cfa920248d56'), 'age': 43, 'sex': 'male', 'bmi': 27.8, 'children': 0, 'smoker': 'yes', 'region': 'southwest', 'expenses': 37829.72}
# 1304: {'_id': ObjectId('64e5a010ab40cfa920248d57'), 'age': 42, 'sex': 'male', 'bmi': 24.6, 'children': 2, 'smoker': 'yes', 'region': 'northeast', 'expenses': 21259.38}
# 1305: {'_id': ObjectId('64e5a010ab40cfa920248d58'), 'age': 24, 'sex': 'female', 'bmi': 27.7, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 2464.62}
# 1306: {'_id': ObjectId('64e5a010ab40cfa920248d59'), 'age': 29, 'sex': 'female', 'bmi': 21.9, 'children': 0, 'smoker': 'yes', 'region': 'northeast', 'expenses': 16115.3}
# 1307: {'_id': ObjectId('64e5a010ab40cfa920248d5a'), 'age': 32, 'sex': 'male', 'bmi': 28.1, 'children': 4, 'smoker': 'yes', 'region': 'northwest', 'expenses': 21472.48}
# 1308: {'_id': ObjectId('64e5a010ab40cfa920248d5b'), 'age': 25, 'sex': 'female', 'bmi': 30.2, 'children': 0, 'smoker': 'yes', 'region': 'southwest', 'expenses': 33900.65}
# 1309: {'_id': ObjectId('64e5a010ab40cfa920248d5c'), 'age': 41, 'sex': 'male', 'bmi': 32.2, 'children': 2, 'smoker': 'no', 'region': 'southwest', 'expenses': 6875.96}
# 1310: {'_id': ObjectId('64e5a010ab40cfa920248d5d'), 'age': 42, 'sex': 'male', 'bmi': 26.3, 'children': 1, 'smoker': 'no', 'region': 'northwest', 'expenses': 6940.91}
# 1311: {'_id': ObjectId('64e5a010ab40cfa920248d5e'), 'age': 33, 'sex': 'female', 'bmi': 26.7, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 4571.41}
# 1312: {'_id': ObjectId('64e5a010ab40cfa920248d5f'), 'age': 34, 'sex': 'male', 'bmi': 42.9, 'children': 1, 'smoker': 'no', 'region': 'southwest', 'expenses': 4536.26}
# 1313: {'_id': ObjectId('64e5a010ab40cfa920248d60'), 'age': 19, 'sex': 'female', 'bmi': 34.7, 'children': 2, 'smoker': 'yes', 'region': 'southwest', 'expenses': 36397.58}
# 1314: {'_id': ObjectId('64e5a010ab40cfa920248d61'), 'age': 30, 'sex': 'female', 'bmi': 23.7, 'children': 3, 'smoker': 'yes', 'region': 'northwest', 'expenses': 18765.88}
# 1315: {'_id': ObjectId('64e5a010ab40cfa920248d62'), 'age': 18, 'sex': 'male', 'bmi': 28.3, 'children': 1, 'smoker': 'no', 'region': 'northeast', 'expenses': 11272.33}
# 1316: {'_id': ObjectId('64e5a010ab40cfa920248d63'), 'age': 19, 'sex': 'female', 'bmi': 20.6, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 1731.68}
# 1317: {'_id': ObjectId('64e5a010ab40cfa920248d64'), 'age': 18, 'sex': 'male', 'bmi': 53.1, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 1163.46}
# 1318: {'_id': ObjectId('64e5a010ab40cfa920248d65'), 'age': 35, 'sex': 'male', 'bmi': 39.7, 'children': 4, 'smoker': 'no', 'region': 'northeast', 'expenses': 19496.72}
# 1319: {'_id': ObjectId('64e5a010ab40cfa920248d66'), 'age': 39, 'sex': 'female', 'bmi': 26.3, 'children': 2, 'smoker': 'no', 'region': 'northwest', 'expenses': 7201.7}
# 1320: {'_id': ObjectId('64e5a010ab40cfa920248d67'), 'age': 31, 'sex': 'male', 'bmi': 31.1, 'children': 3, 'smoker': 'no', 'region': 'northwest', 'expenses': 5425.02}
# 1321: {'_id': ObjectId('64e5a010ab40cfa920248d68'), 'age': 62, 'sex': 'male', 'bmi': 26.7, 'children': 0, 'smoker': 'yes', 'region': 'northeast', 'expenses': 28101.33}
# 1322: {'_id': ObjectId('64e5a010ab40cfa920248d69'), 'age': 62, 'sex': 'male', 'bmi': 38.8, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 12981.35}
# 1323: {'_id': ObjectId('64e5a010ab40cfa920248d6a'), 'age': 42, 'sex': 'female', 'bmi': 40.4, 'children': 2, 'smoker': 'yes', 'region': 'southeast', 'expenses': 43896.38}
# 1324: {'_id': ObjectId('64e5a010ab40cfa920248d6b'), 'age': 31, 'sex': 'male', 'bmi': 25.9, 'children': 1, 'smoker': 'no', 'region': 'northwest', 'expenses': 4239.89}
# 1325: {'_id': ObjectId('64e5a010ab40cfa920248d6c'), 'age': 61, 'sex': 'male', 'bmi': 33.5, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 13143.34}
# 1326: {'_id': ObjectId('64e5a010ab40cfa920248d6d'), 'age': 42, 'sex': 'female', 'bmi': 32.9, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 7050.02}
# 1327: {'_id': ObjectId('64e5a010ab40cfa920248d6e'), 'age': 51, 'sex': 'male', 'bmi': 30.0, 'children': 1, 'smoker': 'no', 'region': 'southeast', 'expenses': 9377.9}
# 1328: {'_id': ObjectId('64e5a010ab40cfa920248d6f'), 'age': 23, 'sex': 'female', 'bmi': 24.2, 'children': 2, 'smoker': 'no', 'region': 'northeast', 'expenses': 22395.74}
# 1329: {'_id': ObjectId('64e5a010ab40cfa920248d70'), 'age': 52, 'sex': 'male', 'bmi': 38.6, 'children': 2, 'smoker': 'no', 'region': 'southwest', 'expenses': 10325.21}
# 1330: {'_id': ObjectId('64e5a010ab40cfa920248d71'), 'age': 57, 'sex': 'female', 'bmi': 25.7, 'children': 2, 'smoker': 'no', 'region': 'southeast', 'expenses': 12629.17}
# 1331: {'_id': ObjectId('64e5a010ab40cfa920248d72'), 'age': 23, 'sex': 'female', 'bmi': 33.4, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 10795.94}
# 1332: {'_id': ObjectId('64e5a010ab40cfa920248d73'), 'age': 52, 'sex': 'female', 'bmi': 44.7, 'children': 3, 'smoker': 'no', 'region': 'southwest', 'expenses': 11411.69}
# 1333: {'_id': ObjectId('64e5a010ab40cfa920248d74'), 'age': 50, 'sex': 'male', 'bmi': 31.0, 'children': 3, 'smoker': 'no', 'region': 'northwest', 'expenses': 10600.55}
# 1334: {'_id': ObjectId('64e5a010ab40cfa920248d75'), 'age': 18, 'sex': 'female', 'bmi': 31.9, 'children': 0, 'smoker': 'no', 'region': 'northeast', 'expenses': 2205.98}
# 1335: {'_id': ObjectId('64e5a010ab40cfa920248d76'), 'age': 18, 'sex': 'female', 'bmi': 36.9, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 1629.83}
# 1336: {'_id': ObjectId('64e5a010ab40cfa920248d77'), 'age': 21, 'sex': 'female', 'bmi': 25.8, 'children': 0, 'smoker': 'no', 'region': 'southwest', 'expenses': 2007.95}
# 1337: {'_id': ObjectId('64e5a010ab40cfa920248d78'), 'age': 61, 'sex': 'female', 'bmi': 29.1, 'children': 0, 'smoker': 'yes', 'region': 'northwest', 'expenses': 29141.36}
